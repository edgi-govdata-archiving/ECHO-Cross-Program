# %% [markdown]
# | ![EEW logo](https://github.com/edgi-govdata-archiving/EEW-Image-Assets/blob/master/Jupyter%20instructions/eew.jpg?raw=true) | ![EDGI logo](https://github.com/edgi-govdata-archiving/EEW-Image-Assets/blob/master/Jupyter%20instructions/edgi.png?raw=true) |
# |---|---|
#
# #### This notebook is licensed under GPL 3.0. Please visit our Github repo for more information: https://github.com/edgi-govdata-archiving/ECHO-Cross-Program
# #### The notebook was collaboratively authored by EDGI following our authorship protocol: https://docs.google.com/document/d/1CtDN5ZZ4Zv70fHiBTmWkDJ9mswEipX6eCYrwicP66Xw/
# #### For more information about this project, visit https://www.environmentalenforcementwatch.org/

# %% [markdown]
# #### Note:  This notebook pulls data from a copy of EPA's ECHO database hosted by Stony Brook University. The data sets are updated on a weekly basis, meaning that some of the results from your run may not exactly match those in EEW's Congressional Report Cards. For instance, for each program, the Report Cards show ten facilities that have spent at least three of the past 12 (and for CWA, 13) quarters in non-compliance. These results will therefore change as we enter new parts of the year. In addition, the Report Cards estimate the number of facilities that were active in 2020, since EPA does not provide such figures. Our estimate is based on the number of facilities EPA records as active at the current moment in time. In short, we use active right now (in Spring 2021) as a proxy for active in 2020. This number informs several metrics in the Report Cards - including violations and inspections per 1000 facilities - and these will change as the number of facilities reported as "active" right now by the EPA changes. Please see the CD-Report repo for facility counts and non-compliance rates as we recorded them in mid-September 2020 in order to produce the Report Cards.

# %% [markdown]
# # Examining Data from Multiple EPA Programs
#
# This notebook examines data from the EPA's Enforcement and Compliance History Online (ECHO) database (https://echo.epa.gov/). It includes information from EPA's programs covering air quality (the Clean Air Act, or CAA), water quality (the Clean Water Act, or CWA), and hazardous and other waste processing (the Resource Recovery and Conservation Act, or RCRA).
#
# ECHO data is available for facility violations as well as inspections and enforcement actions by EPA, state and other agencies. The data made accessible here runs from the present day (the database is refreshed weekly) back to 2001, which is when the EPA believes the data to be most reliable. The notebook can be run to produce data for multiple Congressional Districts and states of your choosing.

# %% [markdown]
# ## How to Run
# * A "cell" in a Jupyter notebook is a block of code performing a set of actions making available or using specific data.  The notebook works by running one cell after another, as the notebook user selects offered options.
# * If you click on a gray **code** cell, a little “play button” arrow appears on the left. If you click the play button, it will run the code in that cell (“**running** a cell”). The button will animate. When the animation stops, the cell has finished running.
# ![Where to click to run the cell](https://github.com/edgi-govdata-archiving/EEW-Image-Assets/blob/master/Jupyter%20instructions/pressplay.JPG?raw=true)
# * You may get a warning that the notebook was not authored by Google. We know, we authored them! It’s okay. Click “Run Anyway” to continue.
# ![Error Message](https://github.com/edgi-govdata-archiving/EEW-Image-Assets/blob/master/Jupyter%20instructions/warning-message.JPG?raw=true)
# * **It is important to run cells in order because they depend on each other.**
# * Run all of the cells in a Notebook to make a complete report. Please feel free to look at and **learn about each result as you create it**!

# %% [markdown]
# ---

# %% [markdown]
# # **Let's begin!**

# %% [markdown]
# Hover over the "[ ]" on the top left corner of the cell below and you should see a "play" button appear. Click on it to run the cell then move to the next one.
#
# These first two cells give us access to some external Python code we will need.

# %% [markdown]
# ### 1.  Bring in some code that is stored in a Github project.
# These two github repositories hold Python code that the notebook uses.
# * ECHO_modules holds code that can be used in this and other notebooks--the DataSet class, the make_data_sets() function, etc.
# * The ECHO-Cross-Program repository is the one this notebook is contained in.  We clone it to be able to use the utilities.py file contained in it.

# %%
# !git clone https://github.com/edgi-govdata-archiving/ECHO_modules.git -b watershed-geo
# !pip install geopandas
print("Done!")

# %% [markdown]
# ### 2.  Run a few Python modules.
# These will help us process and visualize the different program data sets later.
# * The DataSet class knows how to read the database for an ECHO data set--e.g. CWA Violations.
# * The utilities.py has Python code that helps with showing charts and maps, making filenames, etc.
# * The make_data_set.py has code that creates a DataSet object for each of the ECHO data sets, using the appropriate database tables.

# %%
# %run ECHO_modules/DataSet.py
# %run ECHO_modules/utilities.py
# %run ECHO_modules/make_data_sets.py
print("Done!")
# Out:
# Done!

# %% [markdown]
# ### 3.  This cell contains the parameters of the notebook run.  You can change the (state, CD) pairs to run the notebook for multiple congressional districts in multiple states.  After setting the (state, CD) pairs you want, you can instruct the notebook to Run All and it will step through all of the remaining cells.  You can then come back and examine the results.
# You can put the state/CD pairs into a file, or enter them in this cell.  To use a file, separate the state from the CD by a comma, one pair on each line.  The default filename is cds_todo.csv, or you can choose your own. Set the read_cds_from_csv to True.  You can augment the state/CD pairs that are in the file by putting them into the state_cds.extend() function as shown.
# If you are not using a file, add your list of state/CD pairs as shown in the state_cds.extend() example.

# %%
region_type = 'State'
should_make_charts = False
read_cds_from_csv = True
cds_filename = 'cds_todo/states_all.csv'
state_cds = []
if ( read_cds_from_csv ):
    from csv import reader
    with open( cds_filename, 'r' ) as read_obj:
        csv_reader = reader( read_obj )
        raw_state_cds = list( map( tuple, csv_reader ))
    state_cds = []
    for state, cd in raw_state_cds:
        if ( cd == '0' ):
            cd = None
        else:
            cd = int( cd )
        state_cds.append((state,cd))
# Specify the state/CD pairs to run. They will be added to any that
# were already read from the file.
# Examples:
# state_cds.extend([('DE',None),('WA',2)])

# data_set_list = ['RCRA Violations', 'RCRA Penalties',
#                  'CAA Violations', 'CAA Penalties',
#                  'CWA Violations', 'CWA Penalties', ] 
                 #CAA Enforcements, CWA Enforcements, RCRA Enforcements
data_set_list = ['RCRA Violations', 'RCRA Inspections', 'RCRA Penalties',
                 'CAA Violations', 'CAA Inspections', 'CAA Penalties', 'Greenhouse Gas Emissions', 
                 'CWA Violations', 'CWA Inspections', 'CWA Penalties', ]

# %% [markdown]
# ### 4. This cell makes the data sets and stores the results for each of them from the database.
# This may take some time to run if you are looking at multiple congressional districts.
# * The data_set_list from cell #3 is given to the make_data_sets() function which creates a DataSet object for each item in the list.
# * Go through each of the (state, cd) pairs in the state_cd list specified in cell #3 and have the DataSet object store results returned by the database for that specific state and CD.
# * Also go through each unique state in the list and store data for the entire state.

# %%
data_sets=make_data_sets( data_set_list )
print( "Congressional District data sets:")
for state, cd in state_cds:
    if ( cd is None ):
        continue
    for ds_key, data_set in data_sets.items():
        print( state + '-' + str(cd) + ' - ' + ds_key )
        data_set.store_results( region_type=region_type, region_value=cd, state=state )

print( "State data sets:")
states = list(set([s_cd[0] for s_cd in state_cds]))  #Use conversion to set to make unique
for state in states:
    for ds_key, data_set in data_sets.items():
        print( state + ' - ' + ds_key )
        data_set.store_results( region_type='State', region_value=None, state=state )
# Out:
# Congressional District data sets:
# State data sets:
# MD - RCRA Violations
# select modified from "Last-Modified" where "name" = 'RCRA_VIOLATIONS'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+modified+from+%22Last-Modified%22+where+%22name%22+%3D+%27RCRA_VIOLATIONS%27&pg
# select * from "RCRA_VIOLATIONS_MVIEW" where "FAC_STATE" = 'MD'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27MD%27&pg
# There were 4587 program records found
# MD - RCRA Inspections
# select modified from "Last-Modified" where "name" = 'RCRA_EVALUATIONS'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+modified+from+%22Last-Modified%22+where+%22name%22+%3D+%27RCRA_EVALUATIONS%27&pg
# select * from "RCRA_EVALUATIONS_MVIEW" where "FAC_STATE" = 'MD'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_EVALUATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27MD%27&pg
# There were 9789 program records found
# MD - RCRA Penalties
# select modified from "Last-Modified" where "name" = 'RCRA_ENFORCEMENTS'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+modified+from+%22Last-Modified%22+where+%22name%22+%3D+%27RCRA_ENFORCEMENTS%27&pg
# select * from "RCRA_ENFORCEMENTS_MVIEW" where "FAC_STATE" = 'MD'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_ENFORCEMENTS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27MD%27&pg
# There were 2646 program records found
# MD - CAA Violations
# select modified from "Last-Modified" where "name" = 'ICIS-AIR_VIOLATION_HISTORY'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+modified+from+%22Last-Modified%22+where+%22name%22+%3D+%27ICIS-AIR_VIOLATION_HISTORY%27&pg
# select * from "AIR_VIOLATIONS_MVIEW" where "FAC_STATE" = 'MD'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27MD%27&pg
# There were 304 program records found
# MD - CAA Inspections
# select modified from "Last-Modified" where "name" = 'ICIS-AIR_FCES_PCES'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+modified+from+%22Last-Modified%22+where+%22name%22+%3D+%27ICIS-AIR_FCES_PCES%27&pg
# select * from "AIR_COMPLIANCE_MVIEW" where "FAC_STATE" = 'MD'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_COMPLIANCE_MVIEW%22+where+%22FAC_STATE%22+%3D+%27MD%27&pg
# There were 53889 program records found
# MD - CAA Penalties
# select modified from "Last-Modified" where "name" = 'ICIS-AIR_FORMAL_ACTIONS'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+modified+from+%22Last-Modified%22+where+%22name%22+%3D+%27ICIS-AIR_FORMAL_ACTIONS%27&pg
# select * from "AIR_FORMAL_ACTIONS_MVIEW" where "FAC_STATE" = 'MD'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_FORMAL_ACTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27MD%27&pg
# There were 532 program records found
# MD - Greenhouse Gas Emissions
# select modified from "Last-Modified" where "name" = 'POLL_RPT_COMBINED_EMISSIONS'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+modified+from+%22Last-Modified%22+where+%22name%22+%3D+%27POLL_RPT_COMBINED_EMISSIONS%27&pg
# select * from "GREENHOUSE_GASES_MVIEW" where "FAC_STATE" = 'MD'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22GREENHOUSE_GASES_MVIEW%22+where+%22FAC_STATE%22+%3D+%27MD%27&pg
# There were 1797 program records found
# MD - CWA Violations
# select modified from "Last-Modified" where "name" = 'NPDES_QNCR_HISTORY'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+modified+from+%22Last-Modified%22+where+%22name%22+%3D+%27NPDES_QNCR_HISTORY%27&pg
# select * from "WATER_QUARTERLY_VIOLATIONS_MVIEW" where "FAC_STATE" = 'MD'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22WATER_QUARTERLY_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27MD%27&pg
# There were 137842 program records found
# MD - CWA Inspections
# select modified from "Last-Modified" where "name" = 'NPDES_INSPECTIONS'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+modified+from+%22Last-Modified%22+where+%22name%22+%3D+%27NPDES_INSPECTIONS%27&pg
# select * from "CLEAN_WATER_INSPECTIONS_MVIEW" where "FAC_STATE" = 'MD'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22CLEAN_WATER_INSPECTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27MD%27&pg
# /home/steve/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   from ipykernel import kernelapp as app
# There were 54586 program records found
# MD - CWA Penalties
# select modified from "Last-Modified" where "name" = 'NPDES_FORMAL_ENFORCEMENT_ACTIONS'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+modified+from+%22Last-Modified%22+where+%22name%22+%3D+%27NPDES_FORMAL_ENFORCEMENT_ACTIONS%27&pg
# select * from "CLEAN_WATER_ENFORCEMENT_ACTIONS_MVIEW" where "FAC_STATE" = 'MD'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22CLEAN_WATER_ENFORCEMENT_ACTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27MD%27&pg
# There were 1211 program records found
# GA - RCRA Violations
# select * from "RCRA_VIOLATIONS_MVIEW" where "FAC_STATE" = 'GA'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27GA%27&pg
# There were 14577 program records found
# GA - RCRA Inspections
# select * from "RCRA_EVALUATIONS_MVIEW" where "FAC_STATE" = 'GA'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_EVALUATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27GA%27&pg
# There were 32184 program records found
# GA - RCRA Penalties
# select * from "RCRA_ENFORCEMENTS_MVIEW" where "FAC_STATE" = 'GA'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_ENFORCEMENTS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27GA%27&pg
# There were 8509 program records found
# GA - CAA Violations
# select * from "AIR_VIOLATIONS_MVIEW" where "FAC_STATE" = 'GA'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27GA%27&pg
# There were 1768 program records found
# GA - CAA Inspections
# select * from "AIR_COMPLIANCE_MVIEW" where "FAC_STATE" = 'GA'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_COMPLIANCE_MVIEW%22+where+%22FAC_STATE%22+%3D+%27GA%27&pg
# There were 55798 program records found
# GA - CAA Penalties
# select * from "AIR_FORMAL_ACTIONS_MVIEW" where "FAC_STATE" = 'GA'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_FORMAL_ACTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27GA%27&pg
# There were 2798 program records found
# GA - Greenhouse Gas Emissions
# select * from "GREENHOUSE_GASES_MVIEW" where "FAC_STATE" = 'GA'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22GREENHOUSE_GASES_MVIEW%22+where+%22FAC_STATE%22+%3D+%27GA%27&pg
# There were 4399 program records found
# GA - CWA Violations
# select * from "WATER_QUARTERLY_VIOLATIONS_MVIEW" where "FAC_STATE" = 'GA'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22WATER_QUARTERLY_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27GA%27&pg
# /home/steve/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: DtypeWarning: Columns (11) have mixed types.Specify dtype option on import or set low_memory=False.
#   from ipykernel import kernelapp as app
# There were 124083 program records found
# GA - CWA Inspections
# select * from "CLEAN_WATER_INSPECTIONS_MVIEW" where "FAC_STATE" = 'GA'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22CLEAN_WATER_INSPECTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27GA%27&pg
# There were 25480 program records found
# GA - CWA Penalties
# select * from "CLEAN_WATER_ENFORCEMENT_ACTIONS_MVIEW" where "FAC_STATE" = 'GA'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22CLEAN_WATER_ENFORCEMENT_ACTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27GA%27&pg
# There were 3146 program records found
# MS - RCRA Violations
# select * from "RCRA_VIOLATIONS_MVIEW" where "FAC_STATE" = 'MS'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27MS%27&pg
# There were 2857 program records found
# MS - RCRA Inspections
# select * from "RCRA_EVALUATIONS_MVIEW" where "FAC_STATE" = 'MS'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_EVALUATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27MS%27&pg
# There were 6993 program records found
# MS - RCRA Penalties
# select * from "RCRA_ENFORCEMENTS_MVIEW" where "FAC_STATE" = 'MS'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_ENFORCEMENTS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27MS%27&pg
# There were 1554 program records found
# MS - CAA Violations
# select * from "AIR_VIOLATIONS_MVIEW" where "FAC_STATE" = 'MS'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27MS%27&pg
# There were 761 program records found
# MS - CAA Inspections
# select * from "AIR_COMPLIANCE_MVIEW" where "FAC_STATE" = 'MS'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_COMPLIANCE_MVIEW%22+where+%22FAC_STATE%22+%3D+%27MS%27&pg
# There were 10002 program records found
# MS - CAA Penalties
# select * from "AIR_FORMAL_ACTIONS_MVIEW" where "FAC_STATE" = 'MS'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_FORMAL_ACTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27MS%27&pg
# There were 561 program records found
# MS - Greenhouse Gas Emissions
# select * from "GREENHOUSE_GASES_MVIEW" where "FAC_STATE" = 'MS'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22GREENHOUSE_GASES_MVIEW%22+where+%22FAC_STATE%22+%3D+%27MS%27&pg
# There were 3156 program records found
# MS - CWA Violations
# select * from "WATER_QUARTERLY_VIOLATIONS_MVIEW" where "FAC_STATE" = 'MS'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22WATER_QUARTERLY_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27MS%27&pg
# There were 106282 program records found
# MS - CWA Inspections
# select * from "CLEAN_WATER_INSPECTIONS_MVIEW" where "FAC_STATE" = 'MS'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22CLEAN_WATER_INSPECTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27MS%27&pg
# There were 29724 program records found
# MS - CWA Penalties
# select * from "CLEAN_WATER_ENFORCEMENT_ACTIONS_MVIEW" where "FAC_STATE" = 'MS'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22CLEAN_WATER_ENFORCEMENT_ACTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27MS%27&pg
# There were 1231 program records found
# RI - RCRA Violations
# select * from "RCRA_VIOLATIONS_MVIEW" where "FAC_STATE" = 'RI'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27RI%27&pg
# There were 6958 program records found
# RI - RCRA Inspections
# select * from "RCRA_EVALUATIONS_MVIEW" where "FAC_STATE" = 'RI'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_EVALUATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27RI%27&pg
# There were 5994 program records found
# RI - RCRA Penalties
# select * from "RCRA_ENFORCEMENTS_MVIEW" where "FAC_STATE" = 'RI'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_ENFORCEMENTS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27RI%27&pg
# There were 2601 program records found
# RI - CAA Violations
# select * from "AIR_VIOLATIONS_MVIEW" where "FAC_STATE" = 'RI'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27RI%27&pg
# There were 269 program records found
# RI - CAA Inspections
# select * from "AIR_COMPLIANCE_MVIEW" where "FAC_STATE" = 'RI'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_COMPLIANCE_MVIEW%22+where+%22FAC_STATE%22+%3D+%27RI%27&pg
# There were 2871 program records found
# RI - CAA Penalties
# select * from "AIR_FORMAL_ACTIONS_MVIEW" where "FAC_STATE" = 'RI'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_FORMAL_ACTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27RI%27&pg
# There were 395 program records found
# RI - Greenhouse Gas Emissions
# select * from "GREENHOUSE_GASES_MVIEW" where "FAC_STATE" = 'RI'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22GREENHOUSE_GASES_MVIEW%22+where+%22FAC_STATE%22+%3D+%27RI%27&pg
# There were 350 program records found
# RI - CWA Violations
# select * from "WATER_QUARTERLY_VIOLATIONS_MVIEW" where "FAC_STATE" = 'RI'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22WATER_QUARTERLY_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27RI%27&pg
# There were 13345 program records found
# RI - CWA Inspections
# select * from "CLEAN_WATER_INSPECTIONS_MVIEW" where "FAC_STATE" = 'RI'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22CLEAN_WATER_INSPECTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27RI%27&pg
# There were 4969 program records found
# RI - CWA Penalties
# select * from "CLEAN_WATER_ENFORCEMENT_ACTIONS_MVIEW" where "FAC_STATE" = 'RI'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22CLEAN_WATER_ENFORCEMENT_ACTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27RI%27&pg
# There were 368 program records found
# NH - RCRA Violations
# select * from "RCRA_VIOLATIONS_MVIEW" where "FAC_STATE" = 'NH'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27NH%27&pg
# There were 4041 program records found
# NH - RCRA Inspections
# select * from "RCRA_EVALUATIONS_MVIEW" where "FAC_STATE" = 'NH'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_EVALUATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27NH%27&pg
# There were 2024 program records found
# NH - RCRA Penalties
# select * from "RCRA_ENFORCEMENTS_MVIEW" where "FAC_STATE" = 'NH'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_ENFORCEMENTS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27NH%27&pg
# There were 1773 program records found
# NH - CAA Violations
# select * from "AIR_VIOLATIONS_MVIEW" where "FAC_STATE" = 'NH'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27NH%27&pg
# There were 143 program records found
# NH - CAA Inspections
# select * from "AIR_COMPLIANCE_MVIEW" where "FAC_STATE" = 'NH'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_COMPLIANCE_MVIEW%22+where+%22FAC_STATE%22+%3D+%27NH%27&pg
# There were 3350 program records found
# NH - CAA Penalties
# select * from "AIR_FORMAL_ACTIONS_MVIEW" where "FAC_STATE" = 'NH'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_FORMAL_ACTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27NH%27&pg
# There were 231 program records found
# NH - Greenhouse Gas Emissions
# select * from "GREENHOUSE_GASES_MVIEW" where "FAC_STATE" = 'NH'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22GREENHOUSE_GASES_MVIEW%22+where+%22FAC_STATE%22+%3D+%27NH%27&pg
# There were 563 program records found
# NH - CWA Violations
# select * from "WATER_QUARTERLY_VIOLATIONS_MVIEW" where "FAC_STATE" = 'NH'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22WATER_QUARTERLY_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27NH%27&pg
# There were 10086 program records found
# NH - CWA Inspections
# select * from "CLEAN_WATER_INSPECTIONS_MVIEW" where "FAC_STATE" = 'NH'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22CLEAN_WATER_INSPECTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27NH%27&pg
# There were 6200 program records found
# NH - CWA Penalties
# select * from "CLEAN_WATER_ENFORCEMENT_ACTIONS_MVIEW" where "FAC_STATE" = 'NH'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22CLEAN_WATER_ENFORCEMENT_ACTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27NH%27&pg
# There were 200 program records found
# CA - RCRA Violations
# select * from "RCRA_VIOLATIONS_MVIEW" where "FAC_STATE" = 'CA'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27CA%27&pg
# There were 20211 program records found
# CA - RCRA Inspections
# select * from "RCRA_EVALUATIONS_MVIEW" where "FAC_STATE" = 'CA'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_EVALUATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27CA%27&pg
# There were 33345 program records found
# CA - RCRA Penalties
# select * from "RCRA_ENFORCEMENTS_MVIEW" where "FAC_STATE" = 'CA'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_ENFORCEMENTS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27CA%27&pg
# There were 13305 program records found
# CA - CAA Violations
# select * from "AIR_VIOLATIONS_MVIEW" where "FAC_STATE" = 'CA'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27CA%27&pg
# There were 11183 program records found
# CA - CAA Inspections
# select * from "AIR_COMPLIANCE_MVIEW" where "FAC_STATE" = 'CA'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_COMPLIANCE_MVIEW%22+where+%22FAC_STATE%22+%3D+%27CA%27&pg
# There were 58900 program records found
# CA - CAA Penalties
# select * from "AIR_FORMAL_ACTIONS_MVIEW" where "FAC_STATE" = 'CA'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_FORMAL_ACTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27CA%27&pg
# There were 13020 program records found
# CA - Greenhouse Gas Emissions
# select * from "GREENHOUSE_GASES_MVIEW" where "FAC_STATE" = 'CA'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22GREENHOUSE_GASES_MVIEW%22+where+%22FAC_STATE%22+%3D+%27CA%27&pg
# There were 13140 program records found
# CA - CWA Violations
# select * from "WATER_QUARTERLY_VIOLATIONS_MVIEW" where "FAC_STATE" = 'CA'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22WATER_QUARTERLY_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27CA%27&pg
# There were 95408 program records found
# CA - CWA Inspections
# select * from "CLEAN_WATER_INSPECTIONS_MVIEW" where "FAC_STATE" = 'CA'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22CLEAN_WATER_INSPECTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27CA%27&pg
# /home/steve/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: DtypeWarning: Columns (10,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   from ipykernel import kernelapp as app
# There were 36582 program records found
# CA - CWA Penalties
# select * from "CLEAN_WATER_ENFORCEMENT_ACTIONS_MVIEW" where "FAC_STATE" = 'CA'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22CLEAN_WATER_ENFORCEMENT_ACTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27CA%27&pg
# There were 3621 program records found
# NM - RCRA Violations
# select * from "RCRA_VIOLATIONS_MVIEW" where "FAC_STATE" = 'NM'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27NM%27&pg
# There were 3346 program records found
# NM - RCRA Inspections
# select * from "RCRA_EVALUATIONS_MVIEW" where "FAC_STATE" = 'NM'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_EVALUATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27NM%27&pg
# There were 4883 program records found
# NM - RCRA Penalties
# select * from "RCRA_ENFORCEMENTS_MVIEW" where "FAC_STATE" = 'NM'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_ENFORCEMENTS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27NM%27&pg
# There were 1854 program records found
# NM - CAA Violations
# select * from "AIR_VIOLATIONS_MVIEW" where "FAC_STATE" = 'NM'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27NM%27&pg
# There were 461 program records found
# NM - CAA Inspections
# select * from "AIR_COMPLIANCE_MVIEW" where "FAC_STATE" = 'NM'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_COMPLIANCE_MVIEW%22+where+%22FAC_STATE%22+%3D+%27NM%27&pg
# There were 9523 program records found
# NM - CAA Penalties
# select * from "AIR_FORMAL_ACTIONS_MVIEW" where "FAC_STATE" = 'NM'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_FORMAL_ACTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27NM%27&pg
# There were 1447 program records found
# NM - Greenhouse Gas Emissions
# select * from "GREENHOUSE_GASES_MVIEW" where "FAC_STATE" = 'NM'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22GREENHOUSE_GASES_MVIEW%22+where+%22FAC_STATE%22+%3D+%27NM%27&pg
# There were 2716 program records found
# NM - CWA Violations
# select * from "WATER_QUARTERLY_VIOLATIONS_MVIEW" where "FAC_STATE" = 'NM'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22WATER_QUARTERLY_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27NM%27&pg
# There were 19998 program records found
# NM - CWA Inspections
# select * from "CLEAN_WATER_INSPECTIONS_MVIEW" where "FAC_STATE" = 'NM'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22CLEAN_WATER_INSPECTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27NM%27&pg
# There were 4102 program records found
# NM - CWA Penalties
# select * from "CLEAN_WATER_ENFORCEMENT_ACTIONS_MVIEW" where "FAC_STATE" = 'NM'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22CLEAN_WATER_ENFORCEMENT_ACTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27NM%27&pg
# There were 1480 program records found
# HI - RCRA Violations
# select * from "RCRA_VIOLATIONS_MVIEW" where "FAC_STATE" = 'HI'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27HI%27&pg
# There were 1898 program records found
# HI - RCRA Inspections
# select * from "RCRA_EVALUATIONS_MVIEW" where "FAC_STATE" = 'HI'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_EVALUATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27HI%27&pg
# There were 2302 program records found
# HI - RCRA Penalties
# select * from "RCRA_ENFORCEMENTS_MVIEW" where "FAC_STATE" = 'HI'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_ENFORCEMENTS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27HI%27&pg
# There were 1196 program records found
# HI - CAA Violations
# select * from "AIR_VIOLATIONS_MVIEW" where "FAC_STATE" = 'HI'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27HI%27&pg
# There were 286 program records found
# HI - CAA Inspections
# select * from "AIR_COMPLIANCE_MVIEW" where "FAC_STATE" = 'HI'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_COMPLIANCE_MVIEW%22+where+%22FAC_STATE%22+%3D+%27HI%27&pg
# There were 1953 program records found
# HI - CAA Penalties
# select * from "AIR_FORMAL_ACTIONS_MVIEW" where "FAC_STATE" = 'HI'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_FORMAL_ACTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27HI%27&pg
# There were 221 program records found
# HI - Greenhouse Gas Emissions
# select * from "GREENHOUSE_GASES_MVIEW" where "FAC_STATE" = 'HI'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22GREENHOUSE_GASES_MVIEW%22+where+%22FAC_STATE%22+%3D+%27HI%27&pg
# There were 755 program records found
# HI - CWA Violations
# select * from "WATER_QUARTERLY_VIOLATIONS_MVIEW" where "FAC_STATE" = 'HI'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22WATER_QUARTERLY_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27HI%27&pg
# There were 8739 program records found
# HI - CWA Inspections
# select * from "CLEAN_WATER_INSPECTIONS_MVIEW" where "FAC_STATE" = 'HI'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22CLEAN_WATER_INSPECTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27HI%27&pg
# There were 4337 program records found
# HI - CWA Penalties
# select * from "CLEAN_WATER_ENFORCEMENT_ACTIONS_MVIEW" where "FAC_STATE" = 'HI'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22CLEAN_WATER_ENFORCEMENT_ACTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27HI%27&pg
# There were 345 program records found
# NY - RCRA Violations
# select * from "RCRA_VIOLATIONS_MVIEW" where "FAC_STATE" = 'NY'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27NY%27&pg
# There were 27625 program records found
# NY - RCRA Inspections
# select * from "RCRA_EVALUATIONS_MVIEW" where "FAC_STATE" = 'NY'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_EVALUATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27NY%27&pg
# /home/steve/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: DtypeWarning: Columns (13) have mixed types.Specify dtype option on import or set low_memory=False.
#   from ipykernel import kernelapp as app
# There were 40481 program records found
# NY - RCRA Penalties
# select * from "RCRA_ENFORCEMENTS_MVIEW" where "FAC_STATE" = 'NY'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_ENFORCEMENTS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27NY%27&pg
# There were 16356 program records found
# NY - CAA Violations
# select * from "AIR_VIOLATIONS_MVIEW" where "FAC_STATE" = 'NY'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27NY%27&pg
# There were 3064 program records found
# NY - CAA Inspections
# select * from "AIR_COMPLIANCE_MVIEW" where "FAC_STATE" = 'NY'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_COMPLIANCE_MVIEW%22+where+%22FAC_STATE%22+%3D+%27NY%27&pg
# There were 95914 program records found
# NY - CAA Penalties
# select * from "AIR_FORMAL_ACTIONS_MVIEW" where "FAC_STATE" = 'NY'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_FORMAL_ACTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27NY%27&pg
# There were 3739 program records found
# NY - Greenhouse Gas Emissions
# select * from "GREENHOUSE_GASES_MVIEW" where "FAC_STATE" = 'NY'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22GREENHOUSE_GASES_MVIEW%22+where+%22FAC_STATE%22+%3D+%27NY%27&pg
# There were 6667 program records found
# NY - CWA Violations
# select * from "WATER_QUARTERLY_VIOLATIONS_MVIEW" where "FAC_STATE" = 'NY'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22WATER_QUARTERLY_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27NY%27&pg
# There were 258229 program records found
# NY - CWA Inspections
# select * from "CLEAN_WATER_INSPECTIONS_MVIEW" where "FAC_STATE" = 'NY'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22CLEAN_WATER_INSPECTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27NY%27&pg
# There were 96981 program records found
# NY - CWA Penalties
# select * from "CLEAN_WATER_ENFORCEMENT_ACTIONS_MVIEW" where "FAC_STATE" = 'NY'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22CLEAN_WATER_ENFORCEMENT_ACTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27NY%27&pg
# There were 6194 program records found
# WV - RCRA Violations
# select * from "RCRA_VIOLATIONS_MVIEW" where "FAC_STATE" = 'WV'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27WV%27&pg
# There were 9823 program records found
# WV - RCRA Inspections
# select * from "RCRA_EVALUATIONS_MVIEW" where "FAC_STATE" = 'WV'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_EVALUATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27WV%27&pg
# There were 17280 program records found
# WV - RCRA Penalties
# select * from "RCRA_ENFORCEMENTS_MVIEW" where "FAC_STATE" = 'WV'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_ENFORCEMENTS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27WV%27&pg
# There were 6985 program records found
# WV - CAA Violations
# select * from "AIR_VIOLATIONS_MVIEW" where "FAC_STATE" = 'WV'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27WV%27&pg
# There were 655 program records found
# WV - CAA Inspections
# select * from "AIR_COMPLIANCE_MVIEW" where "FAC_STATE" = 'WV'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_COMPLIANCE_MVIEW%22+where+%22FAC_STATE%22+%3D+%27WV%27&pg
# There were 14154 program records found
# WV - CAA Penalties
# select * from "AIR_FORMAL_ACTIONS_MVIEW" where "FAC_STATE" = 'WV'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_FORMAL_ACTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27WV%27&pg
# There were 991 program records found
# WV - Greenhouse Gas Emissions
# select * from "GREENHOUSE_GASES_MVIEW" where "FAC_STATE" = 'WV'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22GREENHOUSE_GASES_MVIEW%22+where+%22FAC_STATE%22+%3D+%27WV%27&pg
# There were 3062 program records found
# WV - CWA Violations
# select * from "WATER_QUARTERLY_VIOLATIONS_MVIEW" where "FAC_STATE" = 'WV'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22WATER_QUARTERLY_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27WV%27&pg
# /home/steve/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: DtypeWarning: Columns (22) have mixed types.Specify dtype option on import or set low_memory=False.
#   from ipykernel import kernelapp as app
# There were 232002 program records found
# WV - CWA Inspections
# select * from "CLEAN_WATER_INSPECTIONS_MVIEW" where "FAC_STATE" = 'WV'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22CLEAN_WATER_INSPECTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27WV%27&pg
# There were 33631 program records found
# WV - CWA Penalties
# select * from "CLEAN_WATER_ENFORCEMENT_ACTIONS_MVIEW" where "FAC_STATE" = 'WV'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22CLEAN_WATER_ENFORCEMENT_ACTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27WV%27&pg
# There were 2621 program records found
# OK - RCRA Violations
# select * from "RCRA_VIOLATIONS_MVIEW" where "FAC_STATE" = 'OK'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27OK%27&pg
# There were 3883 program records found
# OK - RCRA Inspections
# select * from "RCRA_EVALUATIONS_MVIEW" where "FAC_STATE" = 'OK'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_EVALUATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27OK%27&pg
# There were 5863 program records found
# OK - RCRA Penalties
# select * from "RCRA_ENFORCEMENTS_MVIEW" where "FAC_STATE" = 'OK'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_ENFORCEMENTS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27OK%27&pg
# There were 2184 program records found
# OK - CAA Violations
# select * from "AIR_VIOLATIONS_MVIEW" where "FAC_STATE" = 'OK'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27OK%27&pg
# There were 2031 program records found
# OK - CAA Inspections
# select * from "AIR_COMPLIANCE_MVIEW" where "FAC_STATE" = 'OK'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_COMPLIANCE_MVIEW%22+where+%22FAC_STATE%22+%3D+%27OK%27&pg
# There were 66121 program records found
# OK - CAA Penalties
# select * from "AIR_FORMAL_ACTIONS_MVIEW" where "FAC_STATE" = 'OK'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_FORMAL_ACTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27OK%27&pg
# There were 1166 program records found
# OK - Greenhouse Gas Emissions
# select * from "GREENHOUSE_GASES_MVIEW" where "FAC_STATE" = 'OK'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22GREENHOUSE_GASES_MVIEW%22+where+%22FAC_STATE%22+%3D+%27OK%27&pg
# There were 7635 program records found
# OK - CWA Violations
# select * from "WATER_QUARTERLY_VIOLATIONS_MVIEW" where "FAC_STATE" = 'OK'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22WATER_QUARTERLY_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27OK%27&pg
# There were 44578 program records found
# OK - CWA Inspections
# select * from "CLEAN_WATER_INSPECTIONS_MVIEW" where "FAC_STATE" = 'OK'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22CLEAN_WATER_INSPECTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27OK%27&pg
# There were 7747 program records found
# OK - CWA Penalties
# select * from "CLEAN_WATER_ENFORCEMENT_ACTIONS_MVIEW" where "FAC_STATE" = 'OK'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22CLEAN_WATER_ENFORCEMENT_ACTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27OK%27&pg
# There were 2942 program records found
# MO - RCRA Violations
# select * from "RCRA_VIOLATIONS_MVIEW" where "FAC_STATE" = 'MO'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27MO%27&pg
# There were 22916 program records found
# MO - RCRA Inspections
# select * from "RCRA_EVALUATIONS_MVIEW" where "FAC_STATE" = 'MO'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_EVALUATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27MO%27&pg
# There were 19261 program records found
# MO - RCRA Penalties
# select * from "RCRA_ENFORCEMENTS_MVIEW" where "FAC_STATE" = 'MO'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_ENFORCEMENTS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27MO%27&pg
# There were 9135 program records found
# MO - CAA Violations
# select * from "AIR_VIOLATIONS_MVIEW" where "FAC_STATE" = 'MO'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27MO%27&pg
# There were 550 program records found
# MO - CAA Inspections
# select * from "AIR_COMPLIANCE_MVIEW" where "FAC_STATE" = 'MO'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_COMPLIANCE_MVIEW%22+where+%22FAC_STATE%22+%3D+%27MO%27&pg
# There were 19390 program records found
# MO - CAA Penalties
# select * from "AIR_FORMAL_ACTIONS_MVIEW" where "FAC_STATE" = 'MO'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_FORMAL_ACTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27MO%27&pg
# There were 1647 program records found
# MO - Greenhouse Gas Emissions
# select * from "GREENHOUSE_GASES_MVIEW" where "FAC_STATE" = 'MO'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22GREENHOUSE_GASES_MVIEW%22+where+%22FAC_STATE%22+%3D+%27MO%27&pg
# There were 3275 program records found
# MO - CWA Violations
# select * from "WATER_QUARTERLY_VIOLATIONS_MVIEW" where "FAC_STATE" = 'MO'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22WATER_QUARTERLY_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27MO%27&pg
# There were 734325 program records found
# MO - CWA Inspections
# select * from "CLEAN_WATER_INSPECTIONS_MVIEW" where "FAC_STATE" = 'MO'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22CLEAN_WATER_INSPECTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27MO%27&pg
# There were 29442 program records found
# MO - CWA Penalties
# select * from "CLEAN_WATER_ENFORCEMENT_ACTIONS_MVIEW" where "FAC_STATE" = 'MO'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22CLEAN_WATER_ENFORCEMENT_ACTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27MO%27&pg
# There were 762 program records found
# MA - RCRA Violations
# select * from "RCRA_VIOLATIONS_MVIEW" where "FAC_STATE" = 'MA'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27MA%27&pg
# There were 18090 program records found
# MA - RCRA Inspections
# select * from "RCRA_EVALUATIONS_MVIEW" where "FAC_STATE" = 'MA'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_EVALUATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27MA%27&pg
# There were 23131 program records found
# MA - RCRA Penalties
# select * from "RCRA_ENFORCEMENTS_MVIEW" where "FAC_STATE" = 'MA'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_ENFORCEMENTS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27MA%27&pg
# There were 9212 program records found
# MA - CAA Violations
# select * from "AIR_VIOLATIONS_MVIEW" where "FAC_STATE" = 'MA'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27MA%27&pg
# There were 773 program records found
# MA - CAA Inspections
# select * from "AIR_COMPLIANCE_MVIEW" where "FAC_STATE" = 'MA'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_COMPLIANCE_MVIEW%22+where+%22FAC_STATE%22+%3D+%27MA%27&pg
# There were 50971 program records found
# MA - CAA Penalties
# select * from "AIR_FORMAL_ACTIONS_MVIEW" where "FAC_STATE" = 'MA'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_FORMAL_ACTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27MA%27&pg
# There were 1337 program records found
# MA - Greenhouse Gas Emissions
# select * from "GREENHOUSE_GASES_MVIEW" where "FAC_STATE" = 'MA'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22GREENHOUSE_GASES_MVIEW%22+where+%22FAC_STATE%22+%3D+%27MA%27&pg
# There were 2538 program records found
# MA - CWA Violations
# select * from "WATER_QUARTERLY_VIOLATIONS_MVIEW" where "FAC_STATE" = 'MA'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22WATER_QUARTERLY_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27MA%27&pg
# There were 32221 program records found
# MA - CWA Inspections
# select * from "CLEAN_WATER_INSPECTIONS_MVIEW" where "FAC_STATE" = 'MA'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22CLEAN_WATER_INSPECTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27MA%27&pg
# There were 10667 program records found
# MA - CWA Penalties
# select * from "CLEAN_WATER_ENFORCEMENT_ACTIONS_MVIEW" where "FAC_STATE" = 'MA'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22CLEAN_WATER_ENFORCEMENT_ACTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27MA%27&pg
# There were 841 program records found
# OH - RCRA Violations
# select * from "RCRA_VIOLATIONS_MVIEW" where "FAC_STATE" = 'OH'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27OH%27&pg
# There were 38912 program records found
# OH - RCRA Inspections
# select * from "RCRA_EVALUATIONS_MVIEW" where "FAC_STATE" = 'OH'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_EVALUATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27OH%27&pg
# There were 41828 program records found
# OH - RCRA Penalties
# select * from "RCRA_ENFORCEMENTS_MVIEW" where "FAC_STATE" = 'OH'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_ENFORCEMENTS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27OH%27&pg
# There were 24916 program records found
# OH - CAA Violations
# select * from "AIR_VIOLATIONS_MVIEW" where "FAC_STATE" = 'OH'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27OH%27&pg
# There were 3288 program records found
# OH - CAA Inspections
# select * from "AIR_COMPLIANCE_MVIEW" where "FAC_STATE" = 'OH'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_COMPLIANCE_MVIEW%22+where+%22FAC_STATE%22+%3D+%27OH%27&pg
# There were 45011 program records found
# OH - CAA Penalties
# select * from "AIR_FORMAL_ACTIONS_MVIEW" where "FAC_STATE" = 'OH'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_FORMAL_ACTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27OH%27&pg
# There were 1871 program records found
# OH - Greenhouse Gas Emissions
# select * from "GREENHOUSE_GASES_MVIEW" where "FAC_STATE" = 'OH'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22GREENHOUSE_GASES_MVIEW%22+where+%22FAC_STATE%22+%3D+%27OH%27&pg
# There were 7271 program records found
# OH - CWA Violations
# select * from "WATER_QUARTERLY_VIOLATIONS_MVIEW" where "FAC_STATE" = 'OH'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22WATER_QUARTERLY_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27OH%27&pg
# There were 161083 program records found
# OH - CWA Inspections
# select * from "CLEAN_WATER_INSPECTIONS_MVIEW" where "FAC_STATE" = 'OH'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22CLEAN_WATER_INSPECTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27OH%27&pg
# There were 38281 program records found
# OH - CWA Penalties
# select * from "CLEAN_WATER_ENFORCEMENT_ACTIONS_MVIEW" where "FAC_STATE" = 'OH'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22CLEAN_WATER_ENFORCEMENT_ACTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27OH%27&pg
# There were 1060 program records found
# IL - RCRA Violations
# select * from "RCRA_VIOLATIONS_MVIEW" where "FAC_STATE" = 'IL'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27IL%27&pg
# There were 14390 program records found
# IL - RCRA Inspections
# select * from "RCRA_EVALUATIONS_MVIEW" where "FAC_STATE" = 'IL'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_EVALUATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27IL%27&pg
# There were 30713 program records found
# IL - RCRA Penalties
# select * from "RCRA_ENFORCEMENTS_MVIEW" where "FAC_STATE" = 'IL'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_ENFORCEMENTS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27IL%27&pg
# There were 6951 program records found
# IL - CAA Violations
# select * from "AIR_VIOLATIONS_MVIEW" where "FAC_STATE" = 'IL'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27IL%27&pg
# There were 3307 program records found
# IL - CAA Inspections
# select * from "AIR_COMPLIANCE_MVIEW" where "FAC_STATE" = 'IL'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_COMPLIANCE_MVIEW%22+where+%22FAC_STATE%22+%3D+%27IL%27&pg
# There were 22147 program records found
# IL - CAA Penalties
# select * from "AIR_FORMAL_ACTIONS_MVIEW" where "FAC_STATE" = 'IL'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_FORMAL_ACTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27IL%27&pg
# There were 3613 program records found
# IL - Greenhouse Gas Emissions
# select * from "GREENHOUSE_GASES_MVIEW" where "FAC_STATE" = 'IL'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22GREENHOUSE_GASES_MVIEW%22+where+%22FAC_STATE%22+%3D+%27IL%27&pg
# There were 7407 program records found
# IL - CWA Violations
# select * from "WATER_QUARTERLY_VIOLATIONS_MVIEW" where "FAC_STATE" = 'IL'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22WATER_QUARTERLY_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27IL%27&pg
# There were 208343 program records found
# IL - CWA Inspections
# select * from "CLEAN_WATER_INSPECTIONS_MVIEW" where "FAC_STATE" = 'IL'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22CLEAN_WATER_INSPECTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27IL%27&pg
# There were 147916 program records found
# IL - CWA Penalties
# select * from "CLEAN_WATER_ENFORCEMENT_ACTIONS_MVIEW" where "FAC_STATE" = 'IL'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22CLEAN_WATER_ENFORCEMENT_ACTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27IL%27&pg
# There were 2915 program records found
# CT - RCRA Violations
# select * from "RCRA_VIOLATIONS_MVIEW" where "FAC_STATE" = 'CT'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27CT%27&pg
# There were 12042 program records found
# CT - RCRA Inspections
# select * from "RCRA_EVALUATIONS_MVIEW" where "FAC_STATE" = 'CT'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_EVALUATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27CT%27&pg
# There were 11408 program records found
# CT - RCRA Penalties
# select * from "RCRA_ENFORCEMENTS_MVIEW" where "FAC_STATE" = 'CT'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_ENFORCEMENTS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27CT%27&pg
# There were 4660 program records found
# CT - CAA Violations
# select * from "AIR_VIOLATIONS_MVIEW" where "FAC_STATE" = 'CT'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27CT%27&pg
# There were 618 program records found
# CT - CAA Inspections
# select * from "AIR_COMPLIANCE_MVIEW" where "FAC_STATE" = 'CT'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_COMPLIANCE_MVIEW%22+where+%22FAC_STATE%22+%3D+%27CT%27&pg
# There were 5420 program records found
# CT - CAA Penalties
# select * from "AIR_FORMAL_ACTIONS_MVIEW" where "FAC_STATE" = 'CT'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_FORMAL_ACTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27CT%27&pg
# There were 968 program records found
# CT - Greenhouse Gas Emissions
# select * from "GREENHOUSE_GASES_MVIEW" where "FAC_STATE" = 'CT'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22GREENHOUSE_GASES_MVIEW%22+where+%22FAC_STATE%22+%3D+%27CT%27&pg
# There were 1500 program records found
# CT - CWA Violations
# select * from "WATER_QUARTERLY_VIOLATIONS_MVIEW" where "FAC_STATE" = 'CT'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22WATER_QUARTERLY_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27CT%27&pg
# There were 16747 program records found
# CT - CWA Inspections
# select * from "CLEAN_WATER_INSPECTIONS_MVIEW" where "FAC_STATE" = 'CT'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22CLEAN_WATER_INSPECTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27CT%27&pg
# There were 18356 program records found
# CT - CWA Penalties
# select * from "CLEAN_WATER_ENFORCEMENT_ACTIONS_MVIEW" where "FAC_STATE" = 'CT'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22CLEAN_WATER_ENFORCEMENT_ACTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27CT%27&pg
# There were 491 program records found
# DC - RCRA Violations
# select * from "RCRA_VIOLATIONS_MVIEW" where "FAC_STATE" = 'DC'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27DC%27&pg
# There were 2491 program records found
# DC - RCRA Inspections
# select * from "RCRA_EVALUATIONS_MVIEW" where "FAC_STATE" = 'DC'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_EVALUATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27DC%27&pg
# There were 10358 program records found
# DC - RCRA Penalties
# select * from "RCRA_ENFORCEMENTS_MVIEW" where "FAC_STATE" = 'DC'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_ENFORCEMENTS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27DC%27&pg
# There were 1624 program records found
# DC - CAA Violations
# select * from "AIR_VIOLATIONS_MVIEW" where "FAC_STATE" = 'DC'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27DC%27&pg
# There were 143 program records found
# DC - CAA Inspections
# select * from "AIR_COMPLIANCE_MVIEW" where "FAC_STATE" = 'DC'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_COMPLIANCE_MVIEW%22+where+%22FAC_STATE%22+%3D+%27DC%27&pg
# There were 2427 program records found
# DC - CAA Penalties
# select * from "AIR_FORMAL_ACTIONS_MVIEW" where "FAC_STATE" = 'DC'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_FORMAL_ACTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27DC%27&pg
# There were 120 program records found
# DC - Greenhouse Gas Emissions
# select * from "GREENHOUSE_GASES_MVIEW" where "FAC_STATE" = 'DC'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22GREENHOUSE_GASES_MVIEW%22+where+%22FAC_STATE%22+%3D+%27DC%27&pg
# There were 164 program records found
# DC - CWA Violations
# select * from "WATER_QUARTERLY_VIOLATIONS_MVIEW" where "FAC_STATE" = 'DC'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22WATER_QUARTERLY_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27DC%27&pg
# There were 1666 program records found
# DC - CWA Inspections
# select * from "CLEAN_WATER_INSPECTIONS_MVIEW" where "FAC_STATE" = 'DC'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22CLEAN_WATER_INSPECTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27DC%27&pg
# There were 911 program records found
# DC - CWA Penalties
# select * from "CLEAN_WATER_ENFORCEMENT_ACTIONS_MVIEW" where "FAC_STATE" = 'DC'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22CLEAN_WATER_ENFORCEMENT_ACTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27DC%27&pg
# There were 110 program records found
# MI - RCRA Violations
# select * from "RCRA_VIOLATIONS_MVIEW" where "FAC_STATE" = 'MI'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27MI%27&pg
# There were 35020 program records found
# MI - RCRA Inspections
# select * from "RCRA_EVALUATIONS_MVIEW" where "FAC_STATE" = 'MI'
# ...
# There were 45967 program records found
# NC - CWA Penalties
# select * from "CLEAN_WATER_ENFORCEMENT_ACTIONS_MVIEW" where "FAC_STATE" = 'NC'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22CLEAN_WATER_ENFORCEMENT_ACTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27NC%27&pg
# There were 11532 program records found
# FL - RCRA Violations
# select * from "RCRA_VIOLATIONS_MVIEW" where "FAC_STATE" = 'FL'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27FL%27&pg
# There were 46862 program records found
# FL - RCRA Inspections
# select * from "RCRA_EVALUATIONS_MVIEW" where "FAC_STATE" = 'FL'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_EVALUATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27FL%27&pg
# There were 65879 program records found
# FL - RCRA Penalties
# select * from "RCRA_ENFORCEMENTS_MVIEW" where "FAC_STATE" = 'FL'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_ENFORCEMENTS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27FL%27&pg
# There were 23196 program records found
# FL - CAA Violations
# select * from "AIR_VIOLATIONS_MVIEW" where "FAC_STATE" = 'FL'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27FL%27&pg
# There were 1653 program records found
# FL - CAA Inspections
# select * from "AIR_COMPLIANCE_MVIEW" where "FAC_STATE" = 'FL'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_COMPLIANCE_MVIEW%22+where+%22FAC_STATE%22+%3D+%27FL%27&pg
# There were 46022 program records found
# FL - CAA Penalties
# select * from "AIR_FORMAL_ACTIONS_MVIEW" where "FAC_STATE" = 'FL'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_FORMAL_ACTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27FL%27&pg
# There were 1484 program records found
# FL - Greenhouse Gas Emissions
# select * from "GREENHOUSE_GASES_MVIEW" where "FAC_STATE" = 'FL'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22GREENHOUSE_GASES_MVIEW%22+where+%22FAC_STATE%22+%3D+%27FL%27&pg
# There were 5137 program records found
# FL - CWA Violations
# select * from "WATER_QUARTERLY_VIOLATIONS_MVIEW" where "FAC_STATE" = 'FL'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22WATER_QUARTERLY_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27FL%27&pg
# There were 98502 program records found
# FL - CWA Inspections
# select * from "CLEAN_WATER_INSPECTIONS_MVIEW" where "FAC_STATE" = 'FL'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22CLEAN_WATER_INSPECTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27FL%27&pg
# There were 37693 program records found
# FL - CWA Penalties
# select * from "CLEAN_WATER_ENFORCEMENT_ACTIONS_MVIEW" where "FAC_STATE" = 'FL'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22CLEAN_WATER_ENFORCEMENT_ACTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27FL%27&pg
# There were 1851 program records found
# KS - RCRA Violations
# select * from "RCRA_VIOLATIONS_MVIEW" where "FAC_STATE" = 'KS'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27KS%27&pg
# There were 20810 program records found
# KS - RCRA Inspections
# select * from "RCRA_EVALUATIONS_MVIEW" where "FAC_STATE" = 'KS'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_EVALUATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27KS%27&pg
# There were 18219 program records found
# KS - RCRA Penalties
# select * from "RCRA_ENFORCEMENTS_MVIEW" where "FAC_STATE" = 'KS'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_ENFORCEMENTS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27KS%27&pg
# There were 10929 program records found
# KS - CAA Violations
# select * from "AIR_VIOLATIONS_MVIEW" where "FAC_STATE" = 'KS'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27KS%27&pg
# There were 770 program records found
# KS - CAA Inspections
# select * from "AIR_COMPLIANCE_MVIEW" where "FAC_STATE" = 'KS'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_COMPLIANCE_MVIEW%22+where+%22FAC_STATE%22+%3D+%27KS%27&pg
# There were 19382 program records found
# KS - CAA Penalties
# select * from "AIR_FORMAL_ACTIONS_MVIEW" where "FAC_STATE" = 'KS'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_FORMAL_ACTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27KS%27&pg
# There were 1031 program records found
# KS - Greenhouse Gas Emissions
# select * from "GREENHOUSE_GASES_MVIEW" where "FAC_STATE" = 'KS'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22GREENHOUSE_GASES_MVIEW%22+where+%22FAC_STATE%22+%3D+%27KS%27&pg
# There were 3547 program records found
# KS - CWA Violations
# select * from "WATER_QUARTERLY_VIOLATIONS_MVIEW" where "FAC_STATE" = 'KS'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22WATER_QUARTERLY_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27KS%27&pg
# There were 104233 program records found
# KS - CWA Inspections
# select * from "CLEAN_WATER_INSPECTIONS_MVIEW" where "FAC_STATE" = 'KS'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22CLEAN_WATER_INSPECTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27KS%27&pg
# There were 11668 program records found
# KS - CWA Penalties
# select * from "CLEAN_WATER_ENFORCEMENT_ACTIONS_MVIEW" where "FAC_STATE" = 'KS'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22CLEAN_WATER_ENFORCEMENT_ACTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27KS%27&pg
# There were 321 program records found
# LA - RCRA Violations
# select * from "RCRA_VIOLATIONS_MVIEW" where "FAC_STATE" = 'LA'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27LA%27&pg
# There were 7407 program records found
# LA - RCRA Inspections
# select * from "RCRA_EVALUATIONS_MVIEW" where "FAC_STATE" = 'LA'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_EVALUATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27LA%27&pg
# There were 18546 program records found
# LA - RCRA Penalties
# select * from "RCRA_ENFORCEMENTS_MVIEW" where "FAC_STATE" = 'LA'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_ENFORCEMENTS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27LA%27&pg
# There were 4851 program records found
# LA - CAA Violations
# select * from "AIR_VIOLATIONS_MVIEW" where "FAC_STATE" = 'LA'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27LA%27&pg
# There were 1336 program records found
# LA - CAA Inspections
# select * from "AIR_COMPLIANCE_MVIEW" where "FAC_STATE" = 'LA'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_COMPLIANCE_MVIEW%22+where+%22FAC_STATE%22+%3D+%27LA%27&pg
# There were 29749 program records found
# LA - CAA Penalties
# select * from "AIR_FORMAL_ACTIONS_MVIEW" where "FAC_STATE" = 'LA'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_FORMAL_ACTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27LA%27&pg
# There were 7261 program records found
# LA - Greenhouse Gas Emissions
# select * from "GREENHOUSE_GASES_MVIEW" where "FAC_STATE" = 'LA'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22GREENHOUSE_GASES_MVIEW%22+where+%22FAC_STATE%22+%3D+%27LA%27&pg
# There were 11335 program records found
# LA - CWA Violations
# select * from "WATER_QUARTERLY_VIOLATIONS_MVIEW" where "FAC_STATE" = 'LA'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22WATER_QUARTERLY_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27LA%27&pg
# There were 401029 program records found
# LA - CWA Inspections
# select * from "CLEAN_WATER_INSPECTIONS_MVIEW" where "FAC_STATE" = 'LA'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22CLEAN_WATER_INSPECTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27LA%27&pg
# There were 35334 program records found
# LA - CWA Penalties
# select * from "CLEAN_WATER_ENFORCEMENT_ACTIONS_MVIEW" where "FAC_STATE" = 'LA'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22CLEAN_WATER_ENFORCEMENT_ACTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27LA%27&pg
# There were 10030 program records found
# ID - RCRA Violations
# select * from "RCRA_VIOLATIONS_MVIEW" where "FAC_STATE" = 'ID'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27ID%27&pg
# There were 2490 program records found
# ID - RCRA Inspections
# select * from "RCRA_EVALUATIONS_MVIEW" where "FAC_STATE" = 'ID'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_EVALUATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27ID%27&pg
# There were 4346 program records found
# ID - RCRA Penalties
# select * from "RCRA_ENFORCEMENTS_MVIEW" where "FAC_STATE" = 'ID'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_ENFORCEMENTS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27ID%27&pg
# There were 1323 program records found
# ID - CAA Violations
# select * from "AIR_VIOLATIONS_MVIEW" where "FAC_STATE" = 'ID'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27ID%27&pg
# There were 248 program records found
# ID - CAA Inspections
# select * from "AIR_COMPLIANCE_MVIEW" where "FAC_STATE" = 'ID'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_COMPLIANCE_MVIEW%22+where+%22FAC_STATE%22+%3D+%27ID%27&pg
# There were 3341 program records found
# ID - CAA Penalties
# select * from "AIR_FORMAL_ACTIONS_MVIEW" where "FAC_STATE" = 'ID'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_FORMAL_ACTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27ID%27&pg
# There were 467 program records found
# ID - Greenhouse Gas Emissions
# select * from "GREENHOUSE_GASES_MVIEW" where "FAC_STATE" = 'ID'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22GREENHOUSE_GASES_MVIEW%22+where+%22FAC_STATE%22+%3D+%27ID%27&pg
# There were 1302 program records found
# ID - CWA Violations
# select * from "WATER_QUARTERLY_VIOLATIONS_MVIEW" where "FAC_STATE" = 'ID'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22WATER_QUARTERLY_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27ID%27&pg
# There were 23840 program records found
# ID - CWA Inspections
# select * from "CLEAN_WATER_INSPECTIONS_MVIEW" where "FAC_STATE" = 'ID'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22CLEAN_WATER_INSPECTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27ID%27&pg
# There were 6282 program records found
# ID - CWA Penalties
# select * from "CLEAN_WATER_ENFORCEMENT_ACTIONS_MVIEW" where "FAC_STATE" = 'ID'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22CLEAN_WATER_ENFORCEMENT_ACTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27ID%27&pg
# There were 616 program records found
# WI - RCRA Violations
# select * from "RCRA_VIOLATIONS_MVIEW" where "FAC_STATE" = 'WI'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27WI%27&pg
# There were 11295 program records found
# WI - RCRA Inspections
# select * from "RCRA_EVALUATIONS_MVIEW" where "FAC_STATE" = 'WI'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_EVALUATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27WI%27&pg
# There were 15793 program records found
# WI - RCRA Penalties
# select * from "RCRA_ENFORCEMENTS_MVIEW" where "FAC_STATE" = 'WI'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_ENFORCEMENTS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27WI%27&pg
# There were 6894 program records found
# WI - CAA Violations
# select * from "AIR_VIOLATIONS_MVIEW" where "FAC_STATE" = 'WI'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27WI%27&pg
# There were 1194 program records found
# WI - CAA Inspections
# select * from "AIR_COMPLIANCE_MVIEW" where "FAC_STATE" = 'WI'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_COMPLIANCE_MVIEW%22+where+%22FAC_STATE%22+%3D+%27WI%27&pg
# There were 6142 program records found
# WI - CAA Penalties
# select * from "AIR_FORMAL_ACTIONS_MVIEW" where "FAC_STATE" = 'WI'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_FORMAL_ACTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27WI%27&pg
# There were 572 program records found
# WI - Greenhouse Gas Emissions
# select * from "GREENHOUSE_GASES_MVIEW" where "FAC_STATE" = 'WI'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22GREENHOUSE_GASES_MVIEW%22+where+%22FAC_STATE%22+%3D+%27WI%27&pg
# There were 4340 program records found
# WI - CWA Violations
# select * from "WATER_QUARTERLY_VIOLATIONS_MVIEW" where "FAC_STATE" = 'WI'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22WATER_QUARTERLY_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27WI%27&pg
# There were 58191 program records found
# WI - CWA Inspections
# select * from "CLEAN_WATER_INSPECTIONS_MVIEW" where "FAC_STATE" = 'WI'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22CLEAN_WATER_INSPECTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27WI%27&pg
# There were 12404 program records found
# WI - CWA Penalties
# select * from "CLEAN_WATER_ENFORCEMENT_ACTIONS_MVIEW" where "FAC_STATE" = 'WI'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22CLEAN_WATER_ENFORCEMENT_ACTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27WI%27&pg
# There were 140 program records found
# NE - RCRA Violations
# select * from "RCRA_VIOLATIONS_MVIEW" where "FAC_STATE" = 'NE'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27NE%27&pg
# There were 4510 program records found
# NE - RCRA Inspections
# select * from "RCRA_EVALUATIONS_MVIEW" where "FAC_STATE" = 'NE'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_EVALUATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27NE%27&pg
# There were 4612 program records found
# NE - RCRA Penalties
# select * from "RCRA_ENFORCEMENTS_MVIEW" where "FAC_STATE" = 'NE'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22RCRA_ENFORCEMENTS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27NE%27&pg
# There were 2114 program records found
# NE - CAA Violations
# select * from "AIR_VIOLATIONS_MVIEW" where "FAC_STATE" = 'NE'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27NE%27&pg
# There were 156 program records found
# NE - CAA Inspections
# select * from "AIR_COMPLIANCE_MVIEW" where "FAC_STATE" = 'NE'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_COMPLIANCE_MVIEW%22+where+%22FAC_STATE%22+%3D+%27NE%27&pg
# There were 9236 program records found
# NE - CAA Penalties
# select * from "AIR_FORMAL_ACTIONS_MVIEW" where "FAC_STATE" = 'NE'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22AIR_FORMAL_ACTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27NE%27&pg
# There were 767 program records found
# NE - Greenhouse Gas Emissions
# select * from "GREENHOUSE_GASES_MVIEW" where "FAC_STATE" = 'NE'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22GREENHOUSE_GASES_MVIEW%22+where+%22FAC_STATE%22+%3D+%27NE%27&pg
# There were 2222 program records found
# NE - CWA Violations
# select * from "WATER_QUARTERLY_VIOLATIONS_MVIEW" where "FAC_STATE" = 'NE'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22WATER_QUARTERLY_VIOLATIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27NE%27&pg
# There were 45606 program records found
# NE - CWA Inspections
# select * from "CLEAN_WATER_INSPECTIONS_MVIEW" where "FAC_STATE" = 'NE'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22CLEAN_WATER_INSPECTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27NE%27&pg
# There were 11004 program records found
# NE - CWA Penalties
# select * from "CLEAN_WATER_ENFORCEMENT_ACTIONS_MVIEW" where "FAC_STATE" = 'NE'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22CLEAN_WATER_ENFORCEMENT_ACTIONS_MVIEW%22+where+%22FAC_STATE%22+%3D+%27NE%27&pg
# There were 246 program records found

# %% [markdown]
# ### 5. This cell will generate a chart for each data set and each (state, Congressional District) pair.
# Call each of the DataSet objects' show_charts() methods to render a chart of the data.

# %%
if ( should_make_charts ):
    for ds_key, data_set in data_sets.items():
        print( ds_key )
        if ( ds_key != 'RCRA Penalties' ):
            data_set.show_charts()

# %% [markdown]
# ### 6. Get the State data for comparisons
# Ask the database for ECHO_EXPORTER records for facilities in the state.
# * state_echo_data is a dictionary with the state name as key and the data as value, for all records.
# * state_echo_active is a dictionary for all records in state_echo_data identified as active.

# %%
states = list(set([s_cd[0] for s_cd in state_cds]))  #Use conversion to set to make unique
state_echo_data = {}
state_echo_active = {}
for state in states:
    state_echo_data[state] = read_file( 'ECHO_EXPORTER', 'State', state, None )
    if ( state_echo_data[state] is None ):
        sql = 'select * from "ECHO_EXPORTER" where "FAC_STATE" = \'{}\''.format( state )
        state_echo_data[state] = get_data( sql, 'REGISTRY_ID' )
        write_dataset( state_echo_data[state], 'ECHO_EXPORTER', 'State', state, None )
    state_echo_active[state] = state_echo_data[state].loc[state_echo_data[state]['FAC_ACTIVE_FLAG']=='Y']
    print( 'There are {} active facilities in {}.'.format( 
        str(state_echo_active[state].shape[0]), state))
# Out:
# select * from "ECHO_EXPORTER" where "FAC_STATE" = 'MD'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22ECHO_EXPORTER%22+where+%22FAC_STATE%22+%3D+%27MD%27&pg
# /home/steve/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3338: DtypeWarning: Columns (5,73,119) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# Wrote CSVs/ECHO_EXPORTER-MD-State.csv
# There are 24689 active facilities in MD.
# select * from "ECHO_EXPORTER" where "FAC_STATE" = 'GA'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22ECHO_EXPORTER%22+where+%22FAC_STATE%22+%3D+%27GA%27&pg
# /home/steve/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3338: DtypeWarning: Columns (5,11,12,73,119) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# Wrote CSVs/ECHO_EXPORTER-GA-State.csv
# There are 58617 active facilities in GA.
# select * from "ECHO_EXPORTER" where "FAC_STATE" = 'MS'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22ECHO_EXPORTER%22+where+%22FAC_STATE%22+%3D+%27MS%27&pg
# /home/steve/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3338: DtypeWarning: Columns (11,119) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# Wrote CSVs/ECHO_EXPORTER-MS-State.csv
# There are 8608 active facilities in MS.
# select * from "ECHO_EXPORTER" where "FAC_STATE" = 'RI'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22ECHO_EXPORTER%22+where+%22FAC_STATE%22+%3D+%27RI%27&pg
# /home/steve/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3338: DtypeWarning: Columns (119) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# Wrote CSVs/ECHO_EXPORTER-RI-State.csv
# There are 4118 active facilities in RI.
# select * from "ECHO_EXPORTER" where "FAC_STATE" = 'NH'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22ECHO_EXPORTER%22+where+%22FAC_STATE%22+%3D+%27NH%27&pg
# /home/steve/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3338: DtypeWarning: Columns (74,119) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# Wrote CSVs/ECHO_EXPORTER-NH-State.csv
# There are 6824 active facilities in NH.
# select * from "ECHO_EXPORTER" where "FAC_STATE" = 'CA'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22ECHO_EXPORTER%22+where+%22FAC_STATE%22+%3D+%27CA%27&pg
# /home/steve/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3338: DtypeWarning: Columns (56,57,74,81,119,130) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# Wrote CSVs/ECHO_EXPORTER-CA-State.csv
# There are 229874 active facilities in CA.
# select * from "ECHO_EXPORTER" where "FAC_STATE" = 'NM'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22ECHO_EXPORTER%22+where+%22FAC_STATE%22+%3D+%27NM%27&pg
# /home/steve/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3338: DtypeWarning: Columns (5,119) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# Wrote CSVs/ECHO_EXPORTER-NM-State.csv
# There are 11310 active facilities in NM.
# select * from "ECHO_EXPORTER" where "FAC_STATE" = 'HI'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22ECHO_EXPORTER%22+where+%22FAC_STATE%22+%3D+%27HI%27&pg
# /home/steve/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3338: DtypeWarning: Columns (5,29,56,57,62,64,74,96,98,104,105,108,110,114,119,122,128,130,131) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# Wrote CSVs/ECHO_EXPORTER-HI-State.csv
# There are 3195 active facilities in HI.
# select * from "ECHO_EXPORTER" where "FAC_STATE" = 'NY'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22ECHO_EXPORTER%22+where+%22FAC_STATE%22+%3D+%27NY%27&pg
# /home/steve/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3338: DtypeWarning: Columns (5,56,119) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# Wrote CSVs/ECHO_EXPORTER-NY-State.csv
# There are 51113 active facilities in NY.
# select * from "ECHO_EXPORTER" where "FAC_STATE" = 'WV'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22ECHO_EXPORTER%22+where+%22FAC_STATE%22+%3D+%27WV%27&pg
# Wrote CSVs/ECHO_EXPORTER-WV-State.csv
# There are 15820 active facilities in WV.
# select * from "ECHO_EXPORTER" where "FAC_STATE" = 'OK'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22ECHO_EXPORTER%22+where+%22FAC_STATE%22+%3D+%27OK%27&pg
# /home/steve/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3338: DtypeWarning: Columns (5,11,73) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# Wrote CSVs/ECHO_EXPORTER-OK-State.csv
# There are 19176 active facilities in OK.
# select * from "ECHO_EXPORTER" where "FAC_STATE" = 'MO'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22ECHO_EXPORTER%22+where+%22FAC_STATE%22+%3D+%27MO%27&pg
# Wrote CSVs/ECHO_EXPORTER-MO-State.csv
# There are 20895 active facilities in MO.
# select * from "ECHO_EXPORTER" where "FAC_STATE" = 'MA'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22ECHO_EXPORTER%22+where+%22FAC_STATE%22+%3D+%27MA%27&pg
# /home/steve/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3338: DtypeWarning: Columns (5,12,119) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# Wrote CSVs/ECHO_EXPORTER-MA-State.csv
# There are 25455 active facilities in MA.
# select * from "ECHO_EXPORTER" where "FAC_STATE" = 'OH'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22ECHO_EXPORTER%22+where+%22FAC_STATE%22+%3D+%27OH%27&pg
# /home/steve/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3338: DtypeWarning: Columns (20,57,74,119) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# Wrote CSVs/ECHO_EXPORTER-OH-State.csv
# There are 29864 active facilities in OH.
# select * from "ECHO_EXPORTER" where "FAC_STATE" = 'IL'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22ECHO_EXPORTER%22+where+%22FAC_STATE%22+%3D+%27IL%27&pg
# /home/steve/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3338: DtypeWarning: Columns (5,11,20,73,74,81,119) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# Wrote CSVs/ECHO_EXPORTER-IL-State.csv
# There are 39993 active facilities in IL.
# select * from "ECHO_EXPORTER" where "FAC_STATE" = 'CT'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22ECHO_EXPORTER%22+where+%22FAC_STATE%22+%3D+%27CT%27&pg
# /home/steve/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3338: DtypeWarning: Columns (5,11,74) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# Wrote CSVs/ECHO_EXPORTER-CT-State.csv
# There are 9349 active facilities in CT.
# select * from "ECHO_EXPORTER" where "FAC_STATE" = 'DC'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22ECHO_EXPORTER%22+where+%22FAC_STATE%22+%3D+%27DC%27&pg
# Wrote CSVs/ECHO_EXPORTER-DC-State.csv
# There are 1690 active facilities in DC.
# select * from "ECHO_EXPORTER" where "FAC_STATE" = 'MI'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22ECHO_EXPORTER%22+where+%22FAC_STATE%22+%3D+%27MI%27&pg
# Wrote CSVs/ECHO_EXPORTER-MI-State.csv
# There are 29308 active facilities in MI.
# select * from "ECHO_EXPORTER" where "FAC_STATE" = 'NV'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22ECHO_EXPORTER%22+where+%22FAC_STATE%22+%3D+%27NV%27&pg
# /home/steve/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3338: DtypeWarning: Columns (12,73,81,119) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# Wrote CSVs/ECHO_EXPORTER-NV-State.csv
# There are 7585 active facilities in NV.
# select * from "ECHO_EXPORTER" where "FAC_STATE" = 'AZ'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22ECHO_EXPORTER%22+where+%22FAC_STATE%22+%3D+%27AZ%27&pg
# /home/steve/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3338: DtypeWarning: Columns (5,56,73,74,81) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# Wrote CSVs/ECHO_EXPORTER-AZ-State.csv
# There are 6892 active facilities in AZ.
# select * from "ECHO_EXPORTER" where "FAC_STATE" = 'IA'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22ECHO_EXPORTER%22+where+%22FAC_STATE%22+%3D+%27IA%27&pg
# /home/steve/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3338: DtypeWarning: Columns (5,73,74,119) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# Wrote CSVs/ECHO_EXPORTER-IA-State.csv
# There are 11379 active facilities in IA.
# select * from "ECHO_EXPORTER" where "FAC_STATE" = 'IN'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22ECHO_EXPORTER%22+where+%22FAC_STATE%22+%3D+%27IN%27&pg
# /home/steve/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3338: DtypeWarning: Columns (12,56,73,119) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# Wrote CSVs/ECHO_EXPORTER-IN-State.csv
# There are 23039 active facilities in IN.
# select * from "ECHO_EXPORTER" where "FAC_STATE" = 'KY'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22ECHO_EXPORTER%22+where+%22FAC_STATE%22+%3D+%27KY%27&pg
# /home/steve/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3338: DtypeWarning: Columns (56,57,64,119,130) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# Wrote CSVs/ECHO_EXPORTER-KY-State.csv
# There are 10179 active facilities in KY.
# select * from "ECHO_EXPORTER" where "FAC_STATE" = 'SC'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22ECHO_EXPORTER%22+where+%22FAC_STATE%22+%3D+%27SC%27&pg
# /home/steve/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3338: DtypeWarning: Columns (5,11,119) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# Wrote CSVs/ECHO_EXPORTER-SC-State.csv
# There are 8467 active facilities in SC.
# select * from "ECHO_EXPORTER" where "FAC_STATE" = 'NJ'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22ECHO_EXPORTER%22+where+%22FAC_STATE%22+%3D+%27NJ%27&pg
# /home/steve/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3338: DtypeWarning: Columns (10,12,20,56,57,74,119,130) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# Wrote CSVs/ECHO_EXPORTER-NJ-State.csv
# There are 27983 active facilities in NJ.
# select * from "ECHO_EXPORTER" where "FAC_STATE" = 'VA'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22ECHO_EXPORTER%22+where+%22FAC_STATE%22+%3D+%27VA%27&pg
# /home/steve/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3338: DtypeWarning: Columns (11,20,119) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# Wrote CSVs/ECHO_EXPORTER-VA-State.csv
# There are 20645 active facilities in VA.
# select * from "ECHO_EXPORTER" where "FAC_STATE" = 'UT'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22ECHO_EXPORTER%22+where+%22FAC_STATE%22+%3D+%27UT%27&pg
# /home/steve/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3338: DtypeWarning: Columns (11,56,57,119) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# Wrote CSVs/ECHO_EXPORTER-UT-State.csv
# There are 13878 active facilities in UT.
# select * from "ECHO_EXPORTER" where "FAC_STATE" = 'TN'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22ECHO_EXPORTER%22+where+%22FAC_STATE%22+%3D+%27TN%27&pg
# Wrote CSVs/ECHO_EXPORTER-TN-State.csv
# There are 14675 active facilities in TN.
# select * from "ECHO_EXPORTER" where "FAC_STATE" = 'GU'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22ECHO_EXPORTER%22+where+%22FAC_STATE%22+%3D+%27GU%27&pg
# Wrote CSVs/ECHO_EXPORTER-GU-State.csv
# There are 346 active facilities in GU.
# select * from "ECHO_EXPORTER" where "FAC_STATE" = 'AL'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22ECHO_EXPORTER%22+where+%22FAC_STATE%22+%3D+%27AL%27&pg
# Wrote CSVs/ECHO_EXPORTER-AL-State.csv
# There are 16582 active facilities in AL.
# select * from "ECHO_EXPORTER" where "FAC_STATE" = 'AR'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22ECHO_EXPORTER%22+where+%22FAC_STATE%22+%3D+%27AR%27&pg
# Wrote CSVs/ECHO_EXPORTER-AR-State.csv
# There are 8286 active facilities in AR.
# select * from "ECHO_EXPORTER" where "FAC_STATE" = 'MN'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22ECHO_EXPORTER%22+where+%22FAC_STATE%22+%3D+%27MN%27&pg
# /home/steve/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3338: DtypeWarning: Columns (5,11,57,73,74,119) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# Wrote CSVs/ECHO_EXPORTER-MN-State.csv
# There are 32940 active facilities in MN.
# select * from "ECHO_EXPORTER" where "FAC_STATE" = 'PA'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22ECHO_EXPORTER%22+where+%22FAC_STATE%22+%3D+%27PA%27&pg
# Wrote CSVs/ECHO_EXPORTER-PA-State.csv
# There are 53426 active facilities in PA.
# select * from "ECHO_EXPORTER" where "FAC_STATE" = 'TX'
# http://portal.gss.stonybrook.edu/echoepa/?query=select+%2A+from+%22ECHO_EXPORTER%22+where+%22FAC_STATE%22+%3D+%27TX%27&pg

# %% [markdown]
# ### 7. Number of currently active facilities regulated in CAA, CWA, RCRRA, GHGRP
# * The program_count() function looks at the ECHO_EXPORTER data that is passed in and counts the number of facilities have the 'flag' parameter set to 'Y' (AIR_FLAG, NPDES_FLAG, RCRA_FLAG, GHG_FLAG)
# * cd_echo_data is a dictionary with key (state, cd), where the state_echo_data is filtered for records of the current CD.
# * cd_echo_active is a dictionary for active facilities in the CD.
# * The number of records from these dictionaries is written into a file named like 'active-facilities_All_pg3', in a directory identified by the state and CD, e.g. "LA2".

# %%
def program_count( echo_data, program, flag, state, cd ):
    count = echo_data.loc[echo_data[flag]=='Y'].shape[0]
    print( 'There are {} active facilities in {} CD {} tracked under {}.'.format( 
        str( count ), state, cd, program))
    return count
    
cd_echo_data = {}
cd_echo_active = {}
for state, cd in state_cds:
    rowdata = []    
    if ( cd is None ):
        this_echo_data = state_echo_data[state]
        filename = make_filename( 'active-facilities_All_pg3', 'State', 
                             None, state )
    else:
        this_echo_data = state_echo_data[state].loc[state_echo_data[state]['FAC_DERIVED_CD113'] == cd]
        cd_echo_data[(state,cd)] = this_echo_data
        filename = make_filename( 'active-facilities_All_pg3', 'Congressional District', 
                             state, cd )
    this_echo_active = this_echo_data.loc[this_echo_data['FAC_ACTIVE_FLAG']=='Y']
    if ( cd is not None ):
        cd_echo_active[(state,cd)] = this_echo_active
    rowdata.append( ['CAA', program_count( this_echo_active, 'CAA', 'AIR_FLAG', state, cd)] )
    rowdata.append( ['CWA', program_count( this_echo_active, 'CWA', 'NPDES_FLAG', state, cd)] )
    rowdata.append( ['RCRA', program_count( this_echo_active, 'RCRA', 'RCRA_FLAG', state, cd)] )
    rowdata.append( ['GHG', program_count( this_echo_active, 'GHG', 'GHG_FLAG', state, cd)] )
    with open( filename, 'w', newline='' ) as csvfile:
        header = ['Program', 'Count']
        writer = csv.writer( csvfile )
        writer.writerow( header )
        writer.writerows( rowdata ) 
        print( "Wrote {}".format( filename ))

# %% [markdown]
# ### 8. Map all currently active facilities in each district

# %%
if ( should_make_charts ):
    import geopandas

    for state, cd in state_cds:
        print( 'Map for {} CD {}'.format( state, cd ))
        if ( cd is None ):
            this_data = state_echo_active[state]
        else:
            this_data = cd_echo_active[(state, cd)]
        # Only map CAA, CWA, RCRA, or GHG facilities active in this district:
        map_data = this_data.loc[(this_data['AIR_FLAG']=="Y") | (this_data['NPDES_FLAG']=="Y") |
                (this_data['RCRA_FLAG']=="Y")| (this_data['GHG_FLAG']=="Y")]
        m = mapper(map_data)
        if ( cd is not None ):
            url = "https://raw.githubusercontent.com/unitedstates/districts/gh-pages/cds/2016/{}-{}/shape.geojson".format( state, str(cd))
            map_data = geopandas.read_file(url)
            w = folium.GeoJson(
                map_data,
                name = "EPA Regions",
            ).add_to(m) #m is the map object created to hold the facility points. we want to add this shape object to that map object
            folium.GeoJsonTooltip(fields=["District"]).add_to(w)

        display( m )

# %% [markdown]
# ### 9. Number of recurring violations - facilities with 3+ quarters out of the last 12 in non-compliance, by each program
# For each unique state and then each CD, we look at active records and count facilities that have 'S' or 'V' violations in 3 or more quarters.  The fields looked at are:
# * CAA - CAA_3YR_COMPL_QTRS_HISTORY
# * CWA - CWA_13QTRS_COMPL_HISTORY (Actually 13 quarters instead of 3 years.)
# * RCRA - RCRA_3YR_COMPL_QTRS_HISTORY
#
# * The get_rowdata() function takes the dataframe passed to it, and looks for records with 'S' or 'V' violations in more than 3 quarters. It divides the violations by the number of facilities, returning the raw count of facilities in violation more than 3 months and the percentage of facilities.

# %%
states = list(set([s_cd[0] for s_cd in state_cds]))  #Use conversion to set to make unique

def get_rowdata( df, field, flag ):
    num_fac = df.loc[df[flag]=='Y'].shape[0]
    if ( num_fac == 0 ):
        return (0,0)
    count_viol = df.loc[((df[field].str.count("S") + 
                df[field].str.count("V")) >= 3)].shape[0]
    fraction_viol = count_viol/num_fac
    print( "    {} facilities with at least 3 quarters in non-compliance over the past 3 years".format( count_viol ))
    print( "    {:.2%} of active facilities with at least 3 quarters in non-compliance over the past 3 years".format( 
           fraction_viol ))
    return (count_viol, fraction_viol * 100.)

rowdata_state = {}
for state in states:
    print( "State: {}".format( state ))
    print( "  CAA")
    rowdata_state[state] = []
    rd = get_rowdata( state_echo_active[state], 'CAA_3YR_COMPL_QTRS_HISTORY', 'AIR_FLAG')
    rowdata_state[state].append([ 'CAA', state, '', rd[0], rd[1]])
    print( "  CWA")
    rd = get_rowdata( state_echo_active[state], 'CWA_13QTRS_COMPL_HISTORY', 'NPDES_FLAG')
    rowdata_state[state].append([ 'CWA', state, '', rd[0], rd[1]])
    print( "  RCRA")
    rd = get_rowdata( state_echo_active[state], 'RCRA_3YR_COMPL_QTRS_HISTORY', 'RCRA_FLAG')
    rowdata_state[state].append([ 'RCRA', state, '', rd[0], rd[1]])

for state, cd in state_cds:
    if ( cd is None ):
        filename = make_filename( 'recurring-violations_All_pg3', 'State',
                             None, state )
        with open( filename, 'w', newline='' ) as csvfile:
            header = ['Program', 'State', '', 'Facilities', 'Percent']
            writer = csv.writer( csvfile )
            writer.writerow( header )
            writer.writerows( rowdata_state[state] ) 
            print( "Wrote {}".format( filename ))
    else:
        filename = make_filename( 'recurring-violations_All_pg3', 'Congressional District',
                             state, cd )
        rowdata_cd = []
        print( "{} - CD {}".format( state, cd ))
        print( "  CAA")
        rd = get_rowdata( cd_echo_active[(state,cd)], 'CAA_3YR_COMPL_QTRS_HISTORY', 'AIR_FLAG')
        rowdata_cd.append([ 'CAA', state, cd, rd[0], rd[1]])
        print( "  CWA")
        rd = get_rowdata( cd_echo_active[(state,cd)], 'CWA_13QTRS_COMPL_HISTORY', 'NPDES_FLAG')
        rowdata_cd.append([ 'CWA', state, cd, rd[0], rd[1]])
        print( "  RCRA")
        rd = get_rowdata( cd_echo_active[(state,cd)], 'RCRA_3YR_COMPL_QTRS_HISTORY', 'RCRA_FLAG')
        rowdata_cd.append([ 'RCRA', state, cd, rd[0], rd[1]])
        with open( filename, 'w', newline='' ) as csvfile:
            header = ['Program', 'State', 'CD', 'Facilities', 'Percent']
            writer = csv.writer( csvfile )
            writer.writerow( header )
            writer.writerows( rowdata_state[state] ) 
            writer.writerows( rowdata_cd )
            print( "Wrote {}".format( filename ))

# %% [markdown]
# ### 10. Percent change in violations (CWA)
# For each CD and then each unique state,
# * the quarter is identified in 5 digits, the 1st 4 are year and then the quarter, as in 20013 for the 3rd quarter of 2001
# * the quarter is stipped off, so that there will now be 4 records for the facility for 2001
# * the values for the 4 types of violations--NUME90Q,NUMCVDT,NUMSVCD,NUMPSCH--are added together, over all facilities, to get a single value for the year
# The results for all years are stored in the dictionary effluent_violations_all, and the value for 2020 in its own effluent_violations_2020 dictionary.  The key for the dictionaries is (state,cd).  These will be used in a later cell.

# %%
effluent_violations_2020 = {}  #For use later
effluent_violations_all = {}  #For use later
states = list(set([s_cd[0] for s_cd in state_cds]))  #Use conversion to set to make unique

def get_cwa_df( df ):
    year = df["YEARQTR"].astype("str").str[0:4:1]
    df["YEARQTR"] = year
    df.rename( columns={'YEARQTR':'YEAR'}, inplace=True )
    # Remove fields not relevant to this graph.
    df = df.drop(columns=['FAC_LAT', 'FAC_LONG', 'FAC_ZIP', 
        'FAC_EPA_REGION', 'FAC_DERIVED_WBD', 'FAC_DERIVED_CD113',
        'FAC_PERCENT_MINORITY', 'FAC_POP_DEN'])
    d = df.groupby(pd.to_datetime(df['YEAR'], format="%Y").dt.to_period("Y")).sum()
    d.index = d.index.strftime('%Y')
    d = d[ d.index > '2000' ]
    d['Total'] = d.sum(axis=1)
    return( d )

for state, cd in state_cds:
    if ( cd is None ):
        continue
    print( "CWA Violations - {} District: {}".format( state, cd ))
    df = data_sets["CWA Violations"].results[('Congressional District', cd, state)].dataframe.copy()
    effluent_violations_all[ (state, cd) ] = get_cwa_df( df )
    display(effluent_violations_all[ (state, cd) ])
    filename = make_filename( 'violations_CWA_pg3', 'Congressional District', 
                             state, cd )
    with open( filename, 'w', newline='' ) as csvfile:
        header = ['Year', 'Violations']
        writer = csv.writer( csvfile )
        writer.writerow( header )
        for row in effluent_violations_all[ (state, cd) ].itertuples():
            if ( row[0] == '2020' ):
                effluent_violations_2020[(state,cd)] = row[5]
            writer.writerow( [ row[0], row[5]] )
        print( "Wrote {}".format( filename ))

for state in states:
    filename = make_filename( 'violations_CWA_pg3', 'State', None, state )
    df = data_sets["CWA Violations"].results[('State', None, state)].dataframe.copy()
    cwa_all_df = get_cwa_df( df )
    effluent_violations_all[ (state, None) ] = cwa_all_df
    effluent_violations_2020[ (state, None) ] = cwa_all_df[cwa_all_df.index == '2020']['NUME90Q'][0]
    with open( filename, 'w', newline='' ) as csvfile:
        header = ['Year', 'Violations']
        writer = csv.writer( csvfile )
        writer.writerow( header )
        for row in cwa_all_df.itertuples():
            if ( row[0] == '2020' ):
                effluent_violations_2020[(state,None)] = row[5]
            writer.writerow( [ row[0], row[5]] )
        print( "Wrote {}".format( filename ))

# %% [markdown]
# ### 11. Percent change in inspections
# For each CD the date field for that program type is used to count up all inspections for the year.  (The date field for each data set is identified in make_data_sets() when the DataSet object is created.  It shows up here as ds.date_field.)

# %%
def get_inspections( ds, ds_type ):
    df0 = ds.results[ ds_type ].dataframe
    if ( df0 is None ):
        return None
    else:
        df_pgm = df0.copy()
    if ( len( df_pgm ) > 0 ):
        df_pgm.rename( columns={ ds.date_field: 'Date',
                            ds.agg_col: 'Count'}, inplace=True )
        df_pgm = df_pgm.groupby(pd.to_datetime(df_pgm['Date'], 
                            format=ds.date_format, errors='coerce'))[['Count']].agg('count')
        df_pgm = df_pgm.resample('Y').sum()
        df_pgm.index = df_pgm.index.strftime('%Y')
        df_pgm = df_pgm[ df_pgm.index > '2000' ]
        display( df_pgm )
    else:
        print( "No records")
    return df_pgm
    
for state, cd in state_cds:
    if ( cd is None ):
        ds_type = ('State', None, state)
    else:
        ds_type = ('Congressional District', cd, state)
    print( "CAA Inspections - {} District: {}".format( state, cd ))
    df_caa = get_inspections( data_sets["CAA Inspections"], ds_type )
    
    print( "CWA Inspections - {} District: {}".format( state, cd ))
    df_cwa = get_inspections( data_sets["CWA Inspections"], ds_type )
   
    print( "RCRA Inspections - {} District: {}".format( state, cd ))
    df_rcra = get_inspections( data_sets["RCRA Inspections"], ds_type )
    
    df_totals = pd.concat( [df_caa, df_cwa, df_rcra] )
    df_totals = df_totals.groupby( df_totals.index ).agg('sum')
    print( "Total inspections for {} district {}".format( state,cd ))
    display( df_totals )
    
    for file in [{"inspections_All_pg3":df_totals}, {"inspections_CAA_pg3":df_caa}, 
                 {"inspections_CWA_pg3":df_cwa}, {"inspections_RCRA_pg3":df_rcra}]:
        if ( cd is None ):
            file_type = ds_type
        else:
            file_type = ('Congressional District', state, cd)
        filename = make_filename( list(file.keys())[0], *file_type )
        df = file.values()
        if ( list(df)[0] is not None ):
            list(df)[0].to_csv( filename )
            print( "Wrote {}".format( filename ))

# %% [markdown]
# ### 12. Percent change in enforcement - penalties and number of enforcements
# * For each CD the number of enforcements and amount of penalty are retrieved from the agg_col field (specified in make_data_sets() for each DataSet).
# * The number of penalties and amount are accummulated for each year.

# %%
def get_enforcements( ds, ds_type ):
    df0 = ds.results[ ds_type ].dataframe
    if ( df0 is None ):
        return None
    else:
        df_pgm = df0.copy()
    if ( len( df_pgm ) > 0 ):
        df_pgm.rename( columns={ ds.date_field: 'Date',
                            ds.agg_col: 'Amount'}, inplace=True )
        if ds.name == "CWA Penalties":
            df_pgm['Amount'] = df_pgm['Amount'].fillna(0) + \
                    df_pgm['STATE_LOCAL_PENALTY_AMT'].fillna(0)                            
        df_pgm["Count"] = 1
        df_pgm = df_pgm.groupby(pd.to_datetime(df_pgm['Date'], 
                format="%m/%d/%Y", errors='coerce')).agg({'Amount':'sum','Count':'count'})

        df_pgm = df_pgm.resample('Y').sum()
        df_pgm.index = df_pgm.index.strftime('%Y')
        df_pgm = df_pgm[ df_pgm.index >= "2001" ]
        display(df_pgm )
    else:
        print( "No records")
    return df_pgm
    
for state, cd in state_cds:
    if ( cd is None ):
        ds_type = ('State', None, state)
        file_type = ds_type
    else:
        ds_type = ('Congressional District', cd, state)
        file_type = ('Congressional District', state, cd)
    print( "CAA Penalties - {} District: {}".format( state, cd ))
    df_caa = get_enforcements( data_sets["CAA Penalties"], ds_type )
    if ( df_caa is not None ):
        filename = make_filename( 'enforcements_CAA_pg5', *file_type )
        df_caa.to_csv( filename )
        print( "Wrote {}".format( filename ))
    
    print( "CWA Penalties - {} District: {}".format( state, cd ))
    df_cwa = get_enforcements( data_sets["CWA Penalties"], ds_type )
    if ( df_cwa is not None ):
        filename = make_filename( 'enforcements_CWA_pg6', *file_type )
        df_cwa.to_csv( filename )
        print( "Wrote {}".format( filename ))
    
    print( "RCRA Penalties - {} District: {}".format( state, cd ))
    df_rcra = get_enforcements( data_sets["RCRA Penalties"], ds_type )
    if ( df_rcra is not None ):
        filename = make_filename( 'enforcements_RCRA_pg7', *file_type )
        df_rcra.to_csv( filename )
        print( "Wrote {}".format( filename ))
    
    df_totals = pd.concat( [df_caa, df_cwa, df_rcra] )
    df_totals = df_totals.groupby( df_totals.index ).agg('sum')
    print( "Total enforcements for {} district {}".format( state,cd ))
    display( df_totals )
    filename = make_filename( 'enforcements_All_pg3', *file_type )
    df_totals.to_csv( filename )
    print( "Wrote {}".format( filename ))

# %% [markdown]
# ### 13.a. 2020 - inspections per 1000 regulated facilities - by district
# * For each CD the inspections data is again grouped into years.
# * The get_num_events() function counts all events it gets from get_events() for the year that is requested, which is 2020.
# * This number is divided by the number of facilities in the district, from the program_count() function of cell #7.
# * The result is multiplied by 1000, equivalent to dividint the denominator (number of facilities) by 1000.

# %%
def get_events( ds, ds_type ):
    df0 = ds.results[ ds_type ].dataframe
    if ( df0 is None ):
        return None
    else:
        df_pgm = df0.copy()
    df_pgm.rename( columns={ ds.date_field: 'Date',
                        ds.agg_col: 'Count'}, inplace=True )
    
    try:
        df_pgm = df_pgm.groupby(pd.to_datetime(df_pgm['Date'], 
                        format=ds.date_format, errors='coerce'))[['Count']].agg('count')
    except ValueError:
        print( "Error with date {}".format(df_pgm['Date']))
    df_pgm = df_pgm.resample('Y').sum()
    df_pgm.index = df_pgm.index.strftime('%Y')
    df_pgm = df_pgm[ df_pgm.index >= '2001']
    return( df_pgm )

def get_num_events( ds, ds_type, state, cd, year='2020' ):
    df_pgm = get_events( ds, ds_type )
    if ( df_pgm is None ):
        return 0
    if ( len( df_pgm ) > 0 ):
        num_events = df_pgm[ df_pgm.index == year ]
        if ( num_events.empty ):
            return 0
        else:
            return num_events['Count'][0]
    
for state, cd in state_cds:
    if ( cd is None ):
        continue
    ds_type = ('Congressional District', cd, state)
    cd_echo_data[(state,cd)] = state_echo_data[state].loc[state_echo_data[state]['FAC_DERIVED_CD113'] == cd]
    cd_echo_active[(state,cd)] = cd_echo_data[(state,cd)].loc[cd_echo_data[(state,cd)]['FAC_ACTIVE_FLAG']=='Y']
    filename = make_filename( 'inspectionsper1000_All_pg4', 'Congressional District', 
                             state, cd )
    with open( filename, 'w', newline='' ) as csvfile:
        header = ['Program', 'Num / 1000']
        writer = csv.writer( csvfile )
        writer.writerow( header )
        try:
            num = 1000. * get_num_events( data_sets["CAA Inspections"], ds_type, state, cd ) / \
                program_count( cd_echo_active[(state,cd)], 'CAA', 'AIR_FLAG', state, cd)
            print("CAA inspections per 1000 regulated facilities: ", num)
            writer.writerow( ['CAA', num] )
        except pd.errors.OutOfBoundsDatetime:
            print( "Bad date in state CWA data")
        try:
            num = 1000. * get_num_events( data_sets["CWA Inspections"], ds_type, state, cd ) / \
                program_count( cd_echo_active[(state,cd)], 'CWA', 'NPDES_FLAG', state, cd)
            print("CWA inspections per 1000 regulated facilities: ", num)
            writer.writerow( ['CWA', num] )
        except pd.errors.OutOfBoundsDatetime:
            print( "Bad date in state CWA data")
        try:
            num = 1000. * get_num_events( data_sets["RCRA Inspections"], ds_type, state, cd ) / \
                program_count( cd_echo_active[(state,cd)], 'RCRA', 'RCRA_FLAG', state, cd)
            print("RCRA inspections per 1000 regulated facilities: ", num)
            writer.writerow( ['RCRA', num] )
        except pd.errors.OutOfBoundsDatetime:
            print( "Bad date in state CWA data")
        print( "Wrote {}".format( filename ))

# %% [markdown]
# ### 13.b. inspections since 2001
# This cell will report no results, but will just save data to some CSVs.
# For each CD, then for each unique state, the get_events() function of cell #13a will return a count of all inspections per year.

# %%
states = list(set([s_cd[0] for s_cd in state_cds]))  #Use conversion to set to make unique

def write_events( ds, ds_type, filename ):
    df_pgm = get_events( ds, ds_type )
    if ( df_pgm is not None ):
        df_pgm.to_csv( filename )
        print( "Wrote {}".format( filename ))
    
for state, cd in state_cds:
    if ( cd is None ):
        continue
    ds_type = ('Congressional District', cd, state)
    filename = make_filename( 'inspections_CAA_pg5', 'Congressional District',
                             state, cd )
    ds = data_sets["CAA Inspections"]
    df_pgm = get_events( ds, ds_type )
    df_pgm.to_csv( filename )
    print( "Wrote {}".format( filename ))
    filename = make_filename( 'inspections_CWA_pg6', 'Congressional District',
                             state, cd )
    ds = data_sets["CWA Inspections"]
    df_pgm = get_events( ds, ds_type )
    df_pgm.to_csv( filename )
    print( "Wrote {}".format( filename ))
    filename = make_filename( 'inspections_RCRA_pg7', 'Congressional District',
                             state, cd )
    ds = data_sets["RCRA Inspections"]
    df_pgm = get_events( ds, ds_type )
    df_pgm.to_csv( filename )
    print( "Wrote {}".format( filename ))

for state in states:
    ds_type = ('State', None, state)
    filename = make_filename( 'inspections_CAA_pg5', *ds_type )
    ds = data_sets["CAA Inspections"]
    write_events( ds, ds_type, filename )
    filename = make_filename( 'inspections_CWA_pg6', *ds_type )
    ds = data_sets["CWA Inspections"]
    write_events( ds, ds_type, filename )
    filename = make_filename( 'inspections_RCRA_pg7', *ds_type )
    ds = data_sets["RCRA Inspections"]
    write_events( ds, ds_type, filename )

# %% [markdown]
# ### 14. 2020 - inspections per 1000 regulated facilities - by state
# This cell repeats the computation done in cell #13a for the full state.  The functions of cell #13a are re-used.

# %%
import shutil

states = list(set([s_cd[0] for s_cd in state_cds]))  #Use conversion to set to make unique

for state in states:
    ds_type = ('State', None, state)
    filename = make_filename( 'inspectionsper1000_All_pg4', *ds_type )
    with open( filename, 'w', newline='' ) as csvfile:
        header = ['Program', 'Num / 1000']
        writer = csv.writer( csvfile )
        writer.writerow( header )
        try: 
            pgm_count = program_count( state_echo_active[state], 'CAA', 'AIR_FLAG', state, None)
            if ( pgm_count == 0 ):
                num = 0
            else:
                num = 1000. * get_num_events( data_sets["CAA Inspections"], ds_type, state, None ) / \
                    pgm_count
            print("CAA inspections per 1000 regulated facilities: ", num)
            writer.writerow( ['CAA', num] )
        except pd.errors.OutOfBoundsDatetime:
            print( "Bad date in state CWA data")
        try:
            pgm_count = program_count( state_echo_active[state], 'CWA', 'NPDES_FLAG', state, None)
            if ( pgm_count == 0 ):
                num = 0
            else:
                num = 1000. * get_num_events( data_sets["CWA Inspections"], ds_type, state, None ) / \
                    pgm_count
            print("CWA inspections per 1000 regulated facilities: ", num)
            writer.writerow( ['CWA', num] )
        except pd.errors.OutOfBoundsDatetime:
            print( "Bad date in state CWA data")
        try:
            pgm_count = program_count( state_echo_active[state], 'RCRA', 'RCRA_FLAG', state, None)
            if ( pgm_count == 0 ):
                num = 0
            else:
                num = 1000. * get_num_events( data_sets["RCRA Inspections"], ds_type, state, None ) / \
                    pgm_count
            print("RCRA inspections per 1000 regulated facilities: ", num)
            writer.writerow( ['RCRA', num] )
        except pd.errors.OutOfBoundsDatetime:
            print( "Bad date in state CWA data")
        print( "Wrote {}".format( filename ))
        
        # Also copy the state's inspectionsper1000 CSV file into the
        # folders for all CDs in the state.
        for cd_state, cd in state_cds:
            if ( cd is None or cd_state != state):
                continue
            dir = 'Output/' + state + str( cd )
            shutil.copy( filename, dir )

# %% [markdown]
# ### 15.a. 2020 - violations per 1000 regulated facilities - by district
# For each CD the get_num_events() function from cell #13a and the program_count() function from cell #7 are re-used with violations data sets this time.  The calculation is the same as in cell #13a.

# %%
for state, cd in state_cds:
    if ( cd is None ):
        continue
    ds_type = ('Congressional District', cd, state)
    filename = make_filename( 'violationsper1000_All_pg4', 'Congressional District', 
                         state, cd )
    with open( filename, 'w', newline='' ) as csvfile:
        header = ['Program', 'Num / 1000']
        writer = csv.writer( csvfile )
        writer.writerow( header )
        try:
            num = 1000. * get_num_events( data_sets["CAA Violations"], ds_type, state, cd ) / \
                program_count( cd_echo_active[(state,cd)], 'CAA', 'AIR_FLAG', state, cd)
            print("CAA violations per 1000 regulated facilities: ", num)
            writer.writerow( ['CAA', num] )
        except pd.errors.OutOfBoundsDatetime:
            print( "Bad date in state CAA data")
        try:
            # Have to handle CWA Violations differently - use saved dictionary from cell 10
            num = effluent_violations_2020[(state,cd)]
            num = 1000. * num / \
                program_count( cd_echo_active[(state,cd)], 'CWA', 'NPDES_FLAG', state, cd)
            print("CWA violations per 1000 regulated facilities: ", num)
            writer.writerow( ['CWA', num] )
        except pd.errors.OutOfBoundsDatetime:
            print( "Bad date in state CWA data")
        try:
            num = 1000. * get_num_events( data_sets["RCRA Violations"], ds_type, state, cd ) / \
                program_count( cd_echo_active[(state,cd)], 'RCRA', 'RCRA_FLAG', state, cd)
            print("RCRA violations per 1000 regulated facilities: ", num)
            writer.writerow( ['RCRA', num] )
        except pd.errors.OutOfBoundsDatetime:
            print( "Bad date in state CWA data")
        print( "Wrote {}".format( filename ))

# %% [markdown]
# ### 15.b. violations since 2001
# The calculation done in cell #13b is repeated for violations.

# %%
for state, cd in state_cds:
    if ( cd is None ):
        ds_type = ('State', None, state)
        file_type = ds_type
    else:
        ds_type = ('Congressional District', cd, state)
        file_type = ('Congressional District', state, cd)
    cd_echo_data[cd] = state_echo_data[state].loc[state_echo_data[state]['FAC_DERIVED_CD113'] == cd]
    filename = make_filename( 'violations_CAA_pg5', *file_type )
    ds = data_sets["CAA Violations"]
    write_events( ds, ds_type, filename )
    filename = make_filename( 'violations_CWA_pg6', *file_type )
    # Have to handle CWA Violations differently - use saved dictionary from cell 10
    effluent_violations_all[ (state, cd) ]['Total'].to_csv( filename )
    print( "Wrote {}".format( filename ))
    filename = make_filename( 'violations_RCRA_pg7', *file_type )
    ds = data_sets["RCRA Violations"]
    write_events( ds, ds_type, filename )

# %% [markdown]
# ### 16. 2020 - violations per 1000 regulated facilities - by state
# The calculations of cell #14 are repeated for violations.

# %%
states = list(set([s_cd[0] for s_cd in state_cds]))  #Use conversion to set to make unique

for state in states:
    ds_type = ('State', None, state)
    filename = make_filename( 'violationsper1000_All_pg4', 'State', None, state )
    with open( filename, 'w', newline='' ) as csvfile:
        header = ['Program', 'Num / 1000']
        writer = csv.writer( csvfile )
        writer.writerow( header )
        try:
            pgm_count = program_count( state_echo_active[state], 'CAA', 'AIR_FLAG', state, None)
            if ( pgm_count == 0 ):
                num = 0
            else:
                num = 1000. * get_num_events( data_sets["CAA Violations"], ds_type, state, None ) / \
                    pgm_count
            print("CAA violations per 1000 regulated facilities: ", num)
            writer.writerow( ['CAA', num] )
        except pd.errors.OutOfBoundsDatetime:
            print( "Bad date in state CAA data")
        try:
            pgm_count = program_count( state_echo_active[state], 'CWA', 'NPDES_FLAG', state, None)
            if ( pgm_count == 0 ):
                num = 0
            else:
                num = 1000. * effluent_violations_2020[ (state, None) ] / \
                    pgm_count
            print("CWA violations per 1000 regulated facilities: ", num)
            writer.writerow( ['CWA', num] )
        except pd.errors.OutOfBoundsDatetime:
            print( "Bad date in state CWA data")
        try:
            pgm_count = program_count( state_echo_active[state], 'RCRA', 'RCRA_FLAG', state, None)
            if ( pgm_count == 0 ):
                num = 0
            else:
                num = 1000. * get_num_events( data_sets["RCRA Violations"], ds_type, state, None ) / \
                    pgm_count
            print("RCRA violations per 1000 regulated facilities: ", num)
            writer.writerow( ['RCRA', num] )
        except pd.errors.OutOfBoundsDatetime:
            print( "Bad date in state RCRA data")
        print( "Wrote {}".format( filename ))

# %% [markdown]
# ### 17. 2020 - enforcement counts and amounts per violating facility - by district
# * The get_num_facilities() function combines the violations into years, then counts the number of facilities with violations for each year.
# * The get_enf_per_fac() function combines enforcements into years, then counts the enforcements and sums the amount of penalties, before dividing by the results from get_num_facilities().
# * These functions are called for each CD, and for CAA, CWA and RCRA.

# %%
def get_num_facilities( program, ds_type, year=2020 ):
    ds = data_sets[program]
    df0 = ds.results[ ds_type ].dataframe
    if ( df0 is None ):
        return 0
    else:
        df_pgm = df0.copy()
    if ( len( df_pgm ) > 0 ):
        df_pgm.rename( columns={ ds.date_field: 'Date',
                            ds.agg_col: 'Count'}, inplace=True )
        if ( program == 'CWA Violations' ):
            yr = df_pgm['Date'].astype( 'str' ).str[0:4:1]
            df_pgm['Date'] = pd.to_datetime( yr, format="%Y" )
        else:
            df_pgm['Date'] = pd.to_datetime( df_pgm['Date'], format=ds.date_format, errors='coerce' )
        df_pgm_year = df_pgm[ df_pgm['Date'].dt.year == year].copy()
        df_pgm_year['Date'] = pd.DatetimeIndex( df_pgm_year['Date']).year
        num_fac = len(df_pgm_year.index.unique())            
        return num_fac

def get_enf_per_fac( ds_enf, ds_type, num_fac, year='2020' ):
    df_pgm = get_enforcements( ds_enf, ds_type )
    if ( df_pgm is None or df_pgm.empty ):
        df_pgm = pd.DataFrame( [[None,None]], columns=['Num_enf_per_fac','Amt_enf_per_fac'])
        print("There were no enforcement actions taken in 2020")
    else:
        df_pgm = df_pgm[ df_pgm.index == "2020" ]
        if ( df_pgm.empty ):
            df_pgm['Num_enf_per_fac'] = None
            df_pgm['Amt_enf_per_fac'] = None
        else:
            df_pgm['Num_enf_per_fac'] = df_pgm.apply( 
              lambda row: None if ( num_fac == 0 ) else row.Count / num_fac, axis=1 )
            df_pgm['Amt_enf_per_fac'] = df_pgm.apply( 
              lambda row: None if ( num_fac == 0 ) else row.Amount / num_fac, axis=1 )
    return df_pgm
    
for state, cd in state_cds:
    if ( cd is None ):
        continue
    ds_type = ('Congressional District', cd, state)
    
    num_fac = get_num_facilities( "CAA Violations", ds_type )
    print( "CAA Penalties - {} District: {} - {} facilities with violations in 2020".format( state, cd, num_fac ))
    df_caa = get_enf_per_fac( data_sets["CAA Penalties"], ds_type, num_fac )
    
    num_fac = get_num_facilities( "CWA Violations", ds_type )
    print( "CWA Penalties - {} District: {} - {} facilities with violations in 2020".format( state, cd, num_fac ))
    df_cwa = get_enf_per_fac( data_sets["CWA Penalties"], ds_type, num_fac )
    
    num_fac = get_num_facilities( "RCRA Violations", ds_type )
    print( "RCRA Penalties - {} District: {} - {} facilities with violations in 2020".format( state, cd, num_fac ))
    df_rcra = get_enf_per_fac( data_sets["RCRA Penalties"], ds_type, num_fac )
    
    df_totals = pd.concat( [df_caa, df_cwa, df_rcra] )
    df_totals = df_totals.groupby( df_totals.index ).agg('sum')
    print( "Total enforcements for {} district {} in 2020".format( state,cd ))
    print( df_totals )
    
    filename = make_filename( 'enforcementsperviolatingfacility_All_pg4', 'Congressional District', 
                             state, cd )
    df_totals.to_csv( filename )
    print( "Wrote {}".format( filename ))

# %% [markdown]
# ### 18. 2020 - enforcement counts and amounts per violating facility - by state
# This cell repeats the calculations of cell #17 for unique states.

# %%
states = list(set([s_cd[0] for s_cd in state_cds]))  #Use conversion to set to make unique

for state in states:
    ds_type = ('State', None, state)

    num_fac = get_num_facilities( "CAA Violations", ds_type )
    print( "CAA Penalties - {} - {} facilities with violations".format( state,  num_fac ))
    df_caa = get_enf_per_fac( data_sets["CAA Penalties"], ds_type, num_fac )
    
    num_fac = get_num_facilities( "CWA Violations", ds_type )
    print( "CWA Penalties - {} - {} facilities with violations".format( state, num_fac ))
    df_cwa = get_enf_per_fac( data_sets["CWA Penalties"], ds_type, num_fac )
    
    num_fac = get_num_facilities( "RCRA Violations", ds_type )
    print( "RCRA Penalties - {} - {} facilities with violations".format( state, num_fac ))
    df_rcra = get_enf_per_fac( data_sets["RCRA Penalties"], ds_type, num_fac )
    
    df_totals = pd.concat( [df_caa, df_cwa, df_rcra] )
    df_totals = df_totals.groupby( df_totals.index ).agg('sum')
    print( "Total enforcements for {} ".format( state ))
    print( df_totals )
    
    filename = make_filename( 'enforcementsperviolatingfacility_All_pg4', 'State', 
                             None, state )
    df_totals.to_csv( filename )
    print( "Wrote {}".format( filename ))

# %% [markdown]
# ### 19.  GHG emissions in these districts and states (2010-2018)
# For each state and then each CD, the get_ghg_emissions() function is called.  It combines emissions records into years and sums the amounts.

# %%
Threadstates = list(set([s_cd[0] for s_cd in state_cds]))  #Use conversion to set to make unique
state_emissions = {}

def get_ghg_emissions( ds, ds_type ):
    df_result = ds.results[ ds_type ].dataframe
    if ( df_result is None ):
        print( "No records" )
        return None
    else:
        df_pgm = df_result.copy()
    if ( df_pgm is not None and len( df_pgm ) > 0 ):
        df_pgm.rename( columns={ ds.date_field: 'Date',
                            ds.agg_col: 'Sum'}, inplace=True )
        df_pgm = df_pgm.groupby(pd.to_datetime(df_pgm['Date'], 
                                format=ds.date_format, errors='coerce'))[['Sum']].agg('sum')
        df_pgm = df_pgm.resample('Y').sum()
        df_pgm.index = df_pgm.index.strftime('%Y')
        #df_pgm = df_pgm[ df_pgm.index == '2018' ]
    else:
        print( "No records")
    return df_pgm

for state in states:
    ds_type = ('State', None, state)
    print( "Greenhouse Gas Emissions - State: {}".format( state ))
    df_ghg = get_ghg_emissions( data_sets["Greenhouse Gas Emissions"], ds_type )
    if ( df_ghg is not None ):
        state_emissions[state] = df_ghg 
        display(state_emissions[state])
        filename = make_filename( 'emissions2018_GHGRP_pg4', 'State', None, state )
        df_ghg.to_csv( filename )
        print( "Wrote GHG emissions data to: ", filename)

for state, cd in state_cds:
    if ( cd is None ):
        continue
    ds_type = ('Congressional District', cd, state)
    print( "Greenhouse Gas Emissions - {} District: {}".format( state, cd ))
    df_ghg = get_ghg_emissions( data_sets["Greenhouse Gas Emissions"], ds_type )
    if (df_ghg is not None):
        display(df_ghg)

        filename = make_filename( 'emissions2018_GHGRP_pg4', 'Congressional District', state, cd )
        join = df_ghg.join(state_emissions[state], lsuffix="_District", rsuffix="_State")
    else:
        join = state_emissions[state]
    join.to_csv(filename)
    print( "Wrote GHG emissions data to: ", filename)

# %% [markdown]
# ### 20. Top 10 facilities with compliance problems over the past 3 years
# * The get_top_violators() function counts non-compliance quarters ('S' and 'V' violations) for facilities and then sorts the facilities.
# * The chart_top_violators() function draws the chart.
# * The functions are called for each CD.

# %%
import seaborn as sns

states = list(set([s_cd[0] for s_cd in state_cds]))  #Use conversion to set to make unique

df_violators = {}


for state, cd in state_cds:
    if ( cd is None ):
        df_active = state_echo_active[state]
        df_type = ('State', None, state)
    else:
        df_active = cd_echo_active[(state,cd)]
        df_type = ('Congressional District', state, cd)
    df_violators[(state,cd,'CAA')] = get_top_violators( df_active, 'AIR_FLAG', state, cd, 
            'CAA_3YR_COMPL_QTRS_HISTORY', 'CAA_FORMAL_ACTION_COUNT', 20 )
    if ( df_violators[(state,cd,'CAA')] is not None ):
        filename = make_filename( 'noncomp_CAA_pg6', *df_type )
        df_violators[(state,cd,'CAA')].to_csv( filename )
        print( "Wrote {}".format( filename ))
        if ( should_make_charts ):
            display( chart_top_violators( df_violators[(state,cd,'CAA')], state, cd, 'CAA' ))
    
    df_violators[(state,cd,'CWA')] = get_top_violators( df_active, 'NPDES_FLAG', state, cd, 
            'CWA_13QTRS_COMPL_HISTORY', 'CWA_FORMAL_ACTION_COUNT', 20 )
    if ( df_violators[(state,cd,'CWA')] is not None ):
        filename = make_filename( 'noncomp_CWA_pg6', *df_type )
        df_violators[(state,cd,'CWA')].to_csv( filename )
        print( "Wrote {}".format( filename ))
        if ( should_make_charts ):
            display( chart_top_violators( df_violators[(state,cd,'CWA')], state, cd, 'CWA' ))
    
    df_violators[(state,cd,'RCRA')] = get_top_violators( df_active, 'RCRA_FLAG', state, cd, 
            'RCRA_3YR_COMPL_QTRS_HISTORY', 'RCRA_FORMAL_ACTION_COUNT', 20 )
    if ( df_violators[(state,cd,'RCRA')] is not None ):
        filename = make_filename( 'noncomp_RCRA_pg7', *df_type )
        df_violators[(state,cd,'RCRA')].to_csv( filename )
        print( "Wrote {}".format( filename ))
        if ( should_make_charts ):
            display( chart_top_violators( df_violators[(state,cd,'RCRA')], state, cd, 'RCRA' ))

# %% [markdown]
# ### 21. Map the top 10 facilities with compliance problems over the past 3 years
# A map is drawn showing the facilities identified in cell #20.

# %%
def violators_map( viol_dict, key ):
    print( 'Map for {}, {} CD {}'.format( key[0], str(key[1]), key[2] ))
    map_data = viol_dict[key]
    if ( map_data is None ):
        print( '    No facilities to map')
        return
    m = mapper(map_data)
    if ( cd is not None ):
        url = "https://raw.githubusercontent.com/unitedstates/districts/gh-pages/cds/2016/{}-{}/shape.geojson".format( state, str(cd))
        map_data = geopandas.read_file(url)
        w = folium.GeoJson(
            map_data,
            name = "EPA Regions",
        ).add_to(m) #m is the map object created to hold the facility points. we want to add this shape object to that map object
        folium.GeoJsonTooltip(fields=["District"]).add_to(w)
    display( m )    

if ( should_make_charts ):
    import geopandas

    for state, cd in state_cds:
        violators_map( df_violators, (state,cd,'CAA') )
        violators_map( df_violators, (state,cd,'CWA') )
        violators_map( df_violators, (state,cd,'RCRA') )
